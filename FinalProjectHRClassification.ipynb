# %% [markdown]
# # **Final Project ML Clasification (HR Analytics Employee Promotion Data)**
#
# **Table of content :**
#
# 1. Business Understanding
# 2. Data Understanding
# 3. EDA (Exploratory Data Analysis)
# 4. Data Preparation and Preprocessing
# 5. Modelling Experiments
# 6. Final Model Evaluation
# 7. Conclusion and Recommendation
# 8. Deployment

# %% [markdown]
# ## **1 Business Understanding**
#
# ### 1.1 Context
# In a large multinational corporation (MNC) with 9 broad verticals across the organization, one of the critical challenges faced by the Human Resources (HR) department is identifying the right employees for promotion, particularly for managerial positions and below. Promotions are not just about filling higher positions; they are about placing the right talent in roles where they can lead, innovate, and contribute significantly to the organization’s success.
#
# Traditionally, the final promotion decisions are announced only after a comprehensive evaluation process, which can sometimes be prolonged. This delay can create a bottleneck in the transition of employees into their new roles, resulting in missed opportunities for the company and potential dissatisfaction among employees who feel they are ready to take on more responsibilities but are held back by the slow process.
#
# For a company of this scale, efficiently managing the promotion cycle is essential to maintaining a dynamic and motivated workforce. HR teams need to ensure that potential candidates are identified and prepared well in advance so that the transition to new roles is seamless. By doing so, the company can minimize disruptions, maintain productivity, and foster a culture of growth and development.
#
# The complexity of managing promotions in such a large organization is further compounded by the need to consider various factors such as employee performance, leadership potential, alignment with organizational goals, and the ability to handle increased responsibilities. Therefore, the company requires a systematic approach to identify eligible candidates at specific checkpoints throughout the year, enabling a more agile and efficient promotion cycle.

# %% [markdown]
# ### 1.2 Problem Statement
# Given the importance of timely promotions in maintaining organizational efficiency and employee satisfaction, our main business concern is **how the company can streamline the promotion process for managerial positions and below** by identifying eligible candidates at critical checkpoints. This approach will allow the HR team to expedite the entire promotion cycle, ensuring that the right employees are promoted at the right time, and that transitions into new roles are smooth and efficient.
#
# To achieve this, the company needs to leverage data-driven insights from historical performance evaluations, employee feedback, and other relevant metrics. The goal is to create a predictive model that can identify potential candidates who are ready for promotion, allowing the HR team to proactively prepare them for their new roles. This will not only reduce delays in the promotion process but also enhance employee engagement and retention by providing clear and timely career advancement opportunities. The **main stakeholder of this project will be the HR team, particularly the HR managers responsible for overseeing promotions** across the various verticals within the organization.

# %% [markdown]
# ### 1.3 Key Objectives and Goals
#
# 1. **Resource Optimization**: Optimize the allocation of resources such as training and development activities, focusing on employees most likely to be promoted, thus reducing unnecessary costs and time investments.
# 2. **Improved Promotion Accuracy**: Enhance the accuracy of promotion decisions to reduce the occurrence of promoting unfit candidates (False Positives) and missing out on deserving ones (False Negatives). This would result us to not lose our morale on deserving employees in which the chance they would leave the company could brings a greater loss on the company due to losing a promising employee and spend another budgets on recruitments.
#
# Because, statistically speaking, 82% of managers report they've promoted the wrong person. Our objective would be to minimze the degree in mistaking a promotion. ([Reports of Wrong Promotion](https://www.linkedin.com/pulse/so-looks-like-youve-promoted-wrong-person-rosanna-nadeau-rcxle/))

# %% [markdown]
# ### 1.4 Analytical Approach
#
# **The First step** is to analyze the data to identify patterns that highlight employees with specific characteristics, enabling HR to predict whether these employees are eligible for promotion or not.
#
# **Then finally as the last step,** we build a classification model that will help the company predict which group of candidate employees should be recommended for promotion or not, based on certain evaluation metrics.

# %% [markdown]
# ### 1.5 Confusion Matrix Table
#
# | **Actual vs Predicted**         | **Predicted: Promoted (Positive)** | **Predicted: Not Promoted (Negative)** | **Consequences**                                                                                                                                               |
# |---------------------------------|------------------------------------|----------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Actual: Promoted (Positive)** | True Positive (TP)                 | False Negative (FN)                    | **TP**: Deserving employees are correctly promoted, leading to higher motivation and retention.                                                               |
# |                                 |                                    |                                        | **FN**: Deserving employees are not promoted, leading to potential dissatisfaction, increased attrition, and additional costs associated with hiring and training new employees. While also losing a promising empolyee. |
# | **Actual: Not Promoted (Negative)** | False Positive (FP)                 | True Negative (TN)                      | **FP**: Employees who are not ready or deserving are promoted, leading to wasted promotion costs, time, and training resources, and potential disruption to team performance. |
# |                                 |                                    |                                        | **TN**: Employees who are not ready for promotion are correctly not promoted, ensuring team stability and maintaining performance expectations, while also not wasting unecessary resource for their training.                |

# %% [markdown]
# ### 1.6 Consequential Decision Analysis
#
# **Which is More Dangerous?**
#
# - **FN Risk**: FNs can lead to losing top talent, increased hiring and training costs, and demotivating high performers, which can be costly in both the short and long term.
# - **FP Risk**: FPs result in wasted promotion costs, time, and training resources, and can negatively impact team performance and morale.
#
# **Impacts ?**
#
# - **Short-term**: FPs might seem more immediately costly due to the visible financial and resource impact of promoting the wrong candidates.
# - **Long-term**: FNs can be more damaging over time as they can lead to attrition of key talent, higher hiring and training costs, and a culture where employees feel undervalued.
#
# In many organizational contexts, FNs are considered more dangerous because retaining and recognizing top talent is crucial for long-term success. However, if the organization is particularly sensitive to resource efficiency and team dynamics, FPs might also be considered harmful.
#
# Ultimately, the risk assessment depends on the organization's specific priorities and culture, with both FPs and FNs carrying significant consequences.
#
# **Consequences Simulation**
#
# The cost for hiring an employee in 2024 marks about the average of 4700 USD ([Hiring Cost](https://toggl.com/blog/cost-of-hiring-an-employee))
#
# While the cost for a training is around 1200 USD ([Promotion Training Cost](https://hrdqstore.com/blogs/hrdq-blog/average-cost-employee-training-programs?srsltid=AfmBOoqozYO8rtjrIZhBng9T2_IyEzsYPTAHgtl2TyIWQvJYYMO5DJbF))
#
# This results in our simulation calculation as :
#
# **False Positive (FP) :** **1200** USD per employee
#
# **False Negative (FN) :** 4700 + 1200 = **5900** USD per employee
#
# Leaving us at a greater loss whereas FN occurs compared to FP.

# %% [markdown]
# ### 1.7 Metric Evaluation Choices
#
# In our case, where we need to balance between identifying the right candidates for promotion and minimizing the impact of incorrect predictions, the choice of the F-beta score depends on whether we want to prioritize reducing False Negatives or False Positives:
#
# 1. **False Negatives (FN) are more critical**:
#    - If the impact of missing out on preparing a deserving candidate for promotion is high (e.g., leading to delays in role transition, inefficiencies), you should prioritize **Recall** over Precision.
#    - Use F-beta with **( beta > 1 )** (e.g., 1.5 or 2). This will give more weight to Recall, focusing on reducing False Negatives.
#
# 2. **False Positives (FP) are more critical**:
#    - If the impact of preparing someone for promotion who isn't actually going to be promoted is more problematic (e.g., wasting resources, causing potential disappointment), you should prioritize **Precision** over Recall.
#    - Use F-beta with **( beta < 1 )** (e.g., 0.5). This will give more weight to Precision, focusing on reducing False Positives.
#
# Given the description of our scenario, it seems that **FN** is more consequential than **FP**, Resulting **F-beta** score of **2 (Two)** as our preferred choice for the balance between recall and precision.

# %% [markdown]
# ## **2. Data Understanding**

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score, learning_curve
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier, VotingClassifier
from sklearn.metrics import classification_report, accuracy_score, fbeta_score, roc_auc_score, make_scorer, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.calibration import CalibratedClassifierCV, calibration_curve
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import ADASYN, SMOTE
from imblearn.combine import SMOTEENN
from sklearn.feature_selection import RFECV

# Importing Additional Libraries
import scipy.stats as stats
import joblib
import time
import shap
import phik
from phik import resources, report
from phik.binning import bin_data
from phik.report import plot_correlation_matrix

# Plotting Utilities
import seaborn as sns
import matplotlib.pyplot as plt

# a desperate attempt to remove all those spam outputs
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.1 Data Distribution

# %%
train_data = pd.read_csv('train.csv')

# %%
train_data
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  awards_won?           54808 non-null  int64
#  11  avg_training_score    54808 non-null  int64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 5.4+ MB
# None

# %% [markdown]
# From all the Info above, It is shown that :
#
# | Column Name | Data Type | Description |
# | --- | --- | --- |
# | employee_id            | Integer | Unique ID for employee |
# | department             | String |  Department of employee|
# | region                 | String | Region of employment (unordered) |
# | education              | String | Education Level |
# | gender                 | String | Gender of Employee |
# | recruitment_channel    | String | Channel of recruitment for employee |
# | no_of_trainings        | Integer | No of other trainings completed in previous year on soft skills, technical skills etc |
# | age                    | Integer | Age of Employee |
# | previous_year_rating   | Float |  Employee Rating for the previous year |
# | length_of_service      | Integer | Length of service in years |
# | awards_won?            | Integer | if awards won during previous year then 1 else 0 |
# | avg_training_score     | Integer | Average score in current training evaluations |
# | is_promoted            | Integer |  (Target) Recommended for promotion |
#
# The Train Dataset contains 54808 rows with 13 columns. 5 of the columns are Objects and the rest 8 columns are numerical (including our target features)
#
# Since our main purpose is to classify whether a potential promotee at checkpoint in the test set will be promoted or not after the evaluation process, our attribute **Target** will be `is_promoted` while the rest would be our **Features**

# %% [markdown]
# ### 2.2 Statistical Summary

# %%
display(train_data.describe(), train_data.describe(include=['object']))
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service   awards_won?  avg_training_score   is_promoted
# count       54808.000000  54808.000000        54808.000000  54808.000000
# mean            5.865512      0.023172           63.386750      0.085170
# std             4.265094      0.150450           13.371559      0.279137
# ...

# %%
# Select numeric features, excluding 'employee_id' and 'is_promoted' because employee ID is all unique, and is promoted is our target
numeric_features = train_data.select_dtypes(include=['int64', 'float64']).columns
numeric_features = numeric_features.drop(['employee_id', 'is_promoted'])  # Exclude employee_id and is_promoted

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

axes = axes.flatten()

for i, feature in enumerate(numeric_features):
    sns.boxplot(data=train_data, x=feature, ax=axes[i])
    axes[i].set_title(f'Boxplot of {feature}')

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# This is the barchart version

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

axes = axes.flatten()

for i, feature in enumerate(numeric_features):
    feature_counts = train_data[feature].value_counts().sort_index()
    axes[i].bar(feature_counts.index, feature_counts.values, color='blue', alpha=0.7)
    axes[i].set_title(f'Bar Chart of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')

# %% [markdown]
# From the bar charts presented, we can infer the following observations about the dataset :
#
# 1. **Number of Trainings (`no_of_trainings`)**: The majority of employees have completed very few trainings, with a significant number having only 1 or 2 trainings. Very few employees have undergone more than 4 trainings in the previous year.
#
# 2. **Age (`age`)**: The age distribution shows a peak around the early 30s, with the number of employees gradually decreasing as the age increases. This suggests that the workforce is relatively young, with most employees in their late 20s to early 30s.
#
# 3. **Previous Year Rating (`previous_year_rating`)**: Ratings are heavily concentrated around 3, which may indicate an average or typical performance rating for most employees. There are fewer employees with ratings of 1 or 2, and a moderate number with higher ratings of 4 or 5.
#
# 4. **Length of Service (`length_of_service`)**: Most employees have a length of service of fewer than 10 years, with a steep decline in the number of employees as the length of service increases. This could indicate a relatively young workforce in terms of tenure as well.
#
# 5. **Awards Won (`awards_won?`)**: The vast majority of employees have not won any awards in the previous year, as indicated by the bar showing zero awards. Very few employees have won any awards.
#
# 6. **Average Training Score (`avg_training_score`)**: The average training score distribution shows multiple peaks, suggesting there are several groups of employees with distinct performance levels in training. The scores range from around 40 to 90, with some clusters around the mid-50s, mid-60s, and mid-80s.
#
# **Overall Insights :**
#
# - The workforce seems to be relatively young both in terms of age and length of service.
# - There is a strong concentration of employees with average performance ratings, which might be indicative of a standard evaluation process.
# - Training participation is low, and awards are rare, which might suggest opportunities for increasing employee engagement in developmental activities.
# - The variation in training scores suggests diversity in skill levels or training effectiveness among employees.

# %% [markdown]
# ### 2.3 Missing Values and Duplicates

# %%
# Checking for missing values
train_missing_values = train_data.isnull().sum()

# Checking for duplicates
train_duplicates = train_data.duplicated().sum()

# %%
train_missing_values
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
train_duplicates
# Out:
# 0

# %% [markdown]
# No duplicates exists on our Dataset. Therefore, there is no need to analyze further.

# %%
# Calculate the missing values for the train dataset
missing_train = train_data.isnull().sum()

# Plot the missing values as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(train_data.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values in Train Dataset")
plt.tight_layout()
plt.show()

# %% [markdown]
# To determine if the missing values in the dataset are Missing Completely at Random (MCAR), Missing at Random (MAR), or Missing Not at Random (MNAR), we need to perform some analysis:
#
# 1. **Missing Completely at Random (MCAR):** The missingness is completely random and independent of both observed and unobserved data.
# 2. **Missing at Random (MAR):** The missingness is related to the observed data but not the missing data itself.
# 3. **Missing Not at Random (MNAR):** The missingness is related to the unobserved data, meaning the missing data itself has a pattern.

# %%
# Add a column to indicate where missing values are present in the previous_year_rating column
train_data['missing_previous_year_rating'] = train_data['previous_year_rating'].isnull()

# Check correlations between missing indicator and other columns in the train dataset
train_corr = train_data.corr()

# Select the relevant correlations
missing_corr_train = train_corr['missing_previous_year_rating'].drop('missing_previous_year_rating')

missing_corr_train
# Out:
# employee_id             0.002018
# no_of_trainings         0.026745
# age                    -0.295318
# previous_year_rating         NaN
# length_of_service      -0.325408
# awards_won?             0.000202
# avg_training_score     -0.000626
# is_promoted            -0.003033
# Name: missing_previous_year_rating, dtype: float64

# %% [markdown]
# The correlation analysis between the missing values in the `previous_year_rating` column and other variables in the train dataset shows the following:
#
# - **Age and Length of Service:** Both have a moderate negative correlation with the missingness (`age`: -0.295, `length_of_service`: -0.325). This suggests that younger employees or those with shorter service lengths are more likely to have missing `previous_year_rating`.
# - **No significant correlation** was found between missing values and other numeric variables, suggesting that the missingness might be related to specific characteristics of the employees.
#
# **Interpretation :**
#
# - The presence of correlations with `age` and `length_of_service` suggests that the data might be **Missing at Random (MAR)**, as the missingness is related to observed data.
#
# To check if the missing values are definitively MAR, a more detailed analysis or domain knowledge might be needed. However, based on this initial analysis, the missing data is likely not Missing Completely at Random (MCAR) but rather Missing at Random (MAR).

# %% [markdown]
# From the exploration of data and domain knowledge, we found that :
#
# 1. missing `previous_year_rating` is caused by any rows that has only **1 Year** of `length_of_service`
#
# 2. Based from our assumptions, the reason that causes `education` column to be missing is the employee did not specify their education, or the data was forgotten to be filled. This assumption was realized because for the uneducated or below degree, it is already written as *below secondary*.

# %%
# Analyze correlation with missingness in education by creating a binary indicator for missing values
train_data['education_missing'] = train_data['education'].isnull().astype(int)

# Calculate correlations with the new 'education_missing' column
missing_correlations = train_data.corr()['education_missing'].sort_values(ascending=False)

missing_correlations
# Out:
# education_missing               1.000000
# missing_previous_year_rating    0.068744
# employee_id                     0.002404
# awards_won?                     0.000106
# no_of_trainings                -0.024470
# is_promoted                    -0.026521
# previous_year_rating           -0.032182
# length_of_service              -0.073312
# avg_training_score             -0.083869
# age                            -0.107348
# Name: education_missing, dtype: float64

# %% [markdown]
# **Interpretation :**
#
# 1. The weak correlations overall suggest that the missing education data is not strongly related to any of these features.
#
# 2. The slightly stronger negative correlation with age could indicate that younger employees are slightly more likely to have missing education data, but the correlation is still weak.

# %% [markdown]
# And because of this, we have decided on how to treat our missing values. By doing :
#
# 1. Fill in all the missing values from `previous_year_rating` with ***0 (Zero)*** because as it is known by now, those missing values are the result of no previous year the employee had worked since it is their first year of working. Thus resulting of no rating from the previous year
#
# 2. Fill in all the missing values from `education` with ***unspecified*** text. The reason is as stated from our explanation just above this set of markdown.

# %%
# Fill missing values for previous_year_rating with 0
train_data['previous_year_rating'].fillna(0, inplace=True)

# Fill missing values for education with 'unspecified'
train_data['education'].fillna('unspecified', inplace=True)

# Verify the transformations by checking if there are any missing values left
missing_values_train = train_data.isnull().sum()

# %%
missing_values_train
# Out:
# employee_id                     0
# department                      0
# region                          0
# education                       0
# gender                          0
# recruitment_channel             0
# no_of_trainings                 0
# age                             0
# previous_year_rating            0
# length_of_service               0
# awards_won?                     0
# avg_training_score              0
# is_promoted                     0
# missing_previous_year_rating    0
# education_missing               0
# dtype: int64

# %%
# Drop the 'missing_previous_year_rating' and 'missing_education' columns
train_data.drop(['missing_previous_year_rating', 'education_missing'], axis=1, inplace=True)

# %% [markdown]
# ### 2.4 Outliers, Cardinality, Inconsistent and Rare Values

# %% [markdown]
# #### **Outliers :**

# %%
# List of numerical features
numerical_features = ['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'avg_training_score', 'awards_won?']

# %%
# Function to calculate outliers
def find_outliers(df, feature):
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
    return outliers

# Identify outliers for each numerical feature
outliers_dict = {}
for feature in numerical_features:
    outliers_dict[feature] = find_outliers(train_data, feature)
    print(f'Outliers in {feature}:')
    print(outliers_dict[feature].shape[0], 'outliers found')
    print(outliers_dict[feature][[feature]].head(), '\n')
# Out:
# Outliers in no_of_trainings:
# 10430 outliers found
#     no_of_trainings
# 3                 2
# 5                 2
# 13                2
# 24                2
# 31                2
#
# Outliers in age:
# 1435 outliers found
#      age
# 33    57
# 42    59
# 49    56
# 99    60
# 307   58
#
# Outliers in previous_year_rating:
# 0 outliers found
# Empty DataFrame
# Columns: [previous_year_rating]
# Index: []
#
# Outliers in length_of_service:
# 3489 outliers found
#     length_of_service
# 13                 16
# 42                 26
# 60                 17
# 74                 14
# 99                 17
#
# Outliers in avg_training_score:
# 0 outliers found
# Empty DataFrame
# Columns: [avg_training_score]
# Index: []
#
# Outliers in awards_won?:
# 1270 outliers found
#      awards_won?
# 66             1
# 122            1
# 138            1
# 140            1
# 200            1

# %%
# create function to detect outliers using IQR
def detect_outliers(train_data, column):
    Q1 = train_data[column].quantile(0.25)
    Q3 = train_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = train_data.loc[(train_data[column] < lower_bound) | (train_data[column] > upper_bound)]
    print(f"The number of outliers in '{column}' is {len(outliers)} or {(len(outliers)/len(train_data)*100):.2f}% of the total data ({len(train_data)} rows).")

for col in train_data[numerical_features]:
    detect_outliers(train_data, col)
# Out:
# The number of outliers in 'no_of_trainings' is 10430 or 19.03% of the total data (54808 rows).
# The number of outliers in 'age' is 1435 or 2.62% of the total data (54808 rows).
# The number of outliers in 'previous_year_rating' is 0 or 0.00% of the total data (54808 rows).
# The number of outliers in 'length_of_service' is 3489 or 6.37% of the total data (54808 rows).
# The number of outliers in 'avg_training_score' is 0 or 0.00% of the total data (54808 rows).
# The number of outliers in 'awards_won?' is 1270 or 2.32% of the total data (54808 rows).

# %%
# Plot boxplots for numeric columns to detect outliers
plt.figure(figsize=(20, 15))
for i, column in enumerate(numerical_features, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(data=train_data, x=column)
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# The image we provided contains multiple boxplots representing various features related to employee data. Here's what we can infer from each boxplot :
#
# 1. **Number of Trainings**: The majority of employees have undergone 1 to 3 trainings, with a few outliers who have attended up to 10 trainings.
#
# 2. **Age**: The age distribution is centered around the mid-30s, with most employees between 25 and 45 years old. There are a few older outliers above 55 years.
#
# 3. **Previous Year Rating**: The ratings are spread out from 1 to 5, with no extreme outliers, indicating a balanced distribution of performance ratings.
#
# 4. **Length of Service**: Most employees have a length of service between 0 to 10 years. There are some employees with more than 15 years of service, which are considered outliers.
#
# 5. **Average Training Score**: The average training score is normally distributed with scores ranging from 40 to 100, without significant outliers.
#
# 6. **Awards Won**: Most employees have not won awards, as indicated by the distribution centered at 0, with a few employees who have won awards (1), making them outliers.
#
#
#
# **General Observations :**
# - Overall, the data seems to show a relatively normal distribution for most features, with some outliers that may need further investigation depending on their impact on the promotion process.
# - Promotions seem to be rare, and factors such as age, previous year rating, length of service, and number of awards may play a role in determining who gets promoted.

# %% [markdown]
# #### **Cardinality :**

# %%
# check cardinality
(train_data.select_dtypes(include=['object'])
 .nunique()
 .reset_index()
 .rename(columns={0:'count'}))
# Out:
#                  index  count
# 0           department      9
# 1               region     34
# 2            education      4
# 3               gender      2
# 4  recruitment_channel      3

# %% [markdown]
# From the cardinality check results, here’s what we can conclude about the categorical features :
#
# - `department` feature has 9 unique categories. This is a moderate number of categories, and it suggests that the feature is manageable in terms of encoding. Standard one-hot encoding could be applied here without causing too much sparsity in the dataset.
# - `region` feature has 34 unique categories, which is relatively high. This high cardinality can lead to challenges in modeling, such as increased dimensionality, potential overfitting, and the sparsity of data. Given the high cardinality, strategies like **clustering regions**, **target encoding**, or **grouping rare regions into an "Other" category** may be more effective than straightforward one-hot encoding.
# - The rest of the features are of low cardinality feature and is straightforward to handle. One-hot encoding or even label encoding would work well without creating too many additional dimensions.
#
# **Conclusions and Notes :**
#
# **High Cardinality Concern**: The `region` feature, with 34 unique values, stands out due to its high cardinality. This feature might require more sophisticated handling:
#   - **Clustering**: As previously discussed, clustering similar regions based on promotion rates could reduce the number of categories while retaining useful information.
#   - **Target Encoding**: Encoding `region` based on the mean promotion rate could help capture its impact without adding many dimensions.
#   - **Group Rare Categories**: We could also consider grouping less frequent regions into an "Other" category to simplify the feature.
#
# Before we decide how to handle the high cardinality, we will leave it as it is for now until we reached the final step of EDA on chapter 3 so we could get the insights that would help us decide which method should we use or perhaps leave it as it is.

# %% [markdown]
# #### **Inconsistent Values :**

# %%
# check columns with high nunique except education since we have cleaned and explored that one
print(train_data['department'].unique())
print(train_data['region'].unique())
print(train_data['recruitment_channel'].unique())
print(train_data['education'].unique())
# Out:
# ['Sales & Marketing' 'Operations' 'Technology' 'Analytics' 'R&D'
#  'Procurement' 'Finance' 'HR' 'Legal']
# ['region_7' 'region_22' 'region_19' 'region_23' 'region_26' 'region_2'
#  'region_20' 'region_34' 'region_1' 'region_4' 'region_29' 'region_31'
#  'region_15' 'region_14' 'region_11' 'region_5' 'region_28' 'region_17'
#  'region_13' 'region_16' 'region_25' 'region_10' 'region_27' 'region_30'
#  'region_12' 'region_21' 'region_8' 'region_32' 'region_6' 'region_33'
#  'region_24' 'region_3' 'region_9' 'region_18']
# ['sourcing' 'other' 'referred']
# ["Master's & above" "Bachelor's" 'unspecified' 'Below Secondary']

# %% [markdown]
# No inconsistent values found. Therefore, no need to handle any further.

# %% [markdown]
# #### **Rare Values :**

# %%
# Identify categorical columns
categorical_columns = train_data.select_dtypes(include=['object']).columns

# Calculate frequency of unique values in each categorical column
rare_values_report = {}
for column in categorical_columns:
    value_counts = train_data[column].value_counts(normalize=True)
    rare_values_report[column] = value_counts[value_counts < 0.01]  # considering rare if less than 1% frequency

rare_values_report
# Out:
# {'department': Series([], Name: department, dtype: float64),
#  'region': region_24    0.009269
#  region_12    0.009123
#  region_9     0.007663
#  region_21    0.007499
#  region_3     0.006313
#  region_34    0.005328
#  region_33    0.004908
#  region_18    0.000566
#  Name: region, dtype: float64,
#  'education': Series([], Name: education, dtype: float64),
#  'gender': Series([], Name: gender, dtype: float64),
#  'recruitment_channel': Series([], Name: recruitment_channel, dtype: float64)}

# %% [markdown]
# In our dataset, we observed that certain categories within the `region` column had very few occurrences, representing less than 1% of the total data. Handling these rare values is crucial to ensure that the model is robust and not overly influenced by noise or sparsity issues. But, as previously discussed on sub-chapter **Cardinality**, let's leave it as it is for now until we have reached the end of **Chapter 3 EDA**

# %% [markdown]
# #### **Upload the cleaned dataset :**

# %%
train_data
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9       unspecified      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
# Save the cleaned data to a new CSV file
cleaned_file_path = 'cleaned_train_data.csv'
train_data.to_csv(cleaned_file_path, index=False)

cleaned_file_path
# Out:
# 'cleaned_train_data.csv'

# %% [markdown]
# ## **3. Exploratory Data Analysis (EDA)**

# %% [markdown]
# Catergorical Features to Explore :
# 1. How often each 'department' is promoted ?
# 2. Does 'region' affects the promotion rate ?
# 3. is it true that 'education' has any correlations with the rate of promotions ?
# 4. Is it male or female in 'gender' that is most promoted?
# 5. does 'recruitment_channel' affect the promotions rate?
#
# Numerical Features to Explore :
# 1.  Is it true that the higher of each numerical features are, the higher chance for employees to get promoted? and find the correlation between each of them
#
# Target Features Analysis :
# 1. How is the distribution? does it show any sign of imbalance or balance?

# %% [markdown]
# ### **3.1 Categorical Analysis**

# %% [markdown]
# #### Part 1 : Department

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='department',hue='is_promoted',data=train_data)
plt.title('Department Promotion Distribution')
plt.xlabel('Department')
plt.ylabel('Employees')
plt.show()

# %% [markdown]
# The chart above shows that "Sales & Marketing" has the highest number of employees, with "R&D" as the lowest.

# %%
department_promotion_rate = train_data.groupby('department')['is_promoted'].mean()

plt.figure(figsize=(10, 6))
department_promotion_rate.sort_values(ascending=False).plot(kind='bar', colormap='viridis')
plt.title('Promotion Rate by Department')
plt.xlabel('Department')
plt.ylabel('Promotion Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar chart above displays the promotion rates across different departments.
#
# "Technology" have the highest promotion rates compared to others, with "Legal" as the lowest
#
# This indicates that employees in certain departments are promoted more frequently, which could be due to a variety of factors such as the nature of work, opportunities for advancement, or department-specific criteria for promotion.

# %%
# For showing table
department_summary = train_data.groupby('department')['is_promoted'].agg(
    Promotion_Rate='mean', 
    Number_of_Employees_Promoted='sum',
    Total_Employees='count'
).reset_index()

# Sort descending
department_promotion_summary = department_summary.sort_values(by='Promotion_Rate', ascending=False)

department_promotion_summary
# Out:
#           department  Promotion_Rate  Number_of_Employees_Promoted  \
# 8         Technology        0.107593                           768
# 5        Procurement        0.096386                           688
# 0          Analytics        0.095665                           512
# 4         Operations        0.090148                          1023
# 1            Finance        0.081230                           206
# 7  Sales & Marketing        0.072031                          1213
# 6                R&D        0.069069                            69
# 2                 HR        0.056245                           136
# 3              Legal        0.051011                            53
#
#    Total_Employees
# 8             7138
# 5             7138
# 0             5352
# 4            11348
# 1             2536
# 7            16840
# 6              999
# 2             2418
# 3             1039

# %%
from scipy.stats import chi2_contingency

# Create a crosstab between 'is_promoted' and 'department'
contingency_table_dept = pd.crosstab(train_data['is_promoted'], train_data['department'])

# Perform the Chi-Square test
chi2_dept, p_dept, dof_dept, expected_dept = chi2_contingency(contingency_table_dept)

# Output the results
print(f"Chi-Square Statistic: {chi2_dept:.4f}")
print(f"P-Value: {p_dept:.4f}")
print(f"Degrees of Freedom: {dof_dept:.4f}")
# Out:
# Chi-Square Statistic: 151.4264
# P-Value: 0.0000
# Degrees of Freedom: 8.0000

# %% [markdown]
# The very low p-value (close to zero) suggests that there is a statistically significant association between the department and the promotion status (is_promoted). This means that the department an employee belongs to has a significant influence on whether or not they are promoted.

# %% [markdown]
# The strong link between department and promotion rates reflects real-world dynamics where departments differ in roles, resources, and opportunities:
#
# 1. **Departmental Structure**: Departments like Technology or R&D may have more hierarchical levels and opportunities for advancement, while others, like Procurement, may have flatter structures.
#
# 2. **Performance Metrics**: Departments with clear KPIs, such as Sales or Technology, can easily identify top performers, leading to more promotions.
#
# 3. **Resource Allocation**: Well-resourced departments, like Technology, often see higher promotion rates due to better training and development.
#
# 4. **Culture and Leadership**: Strong leadership and a culture of internal promotion in certain departments drive higher promotion rates.
#
# 5. **Market Demand**: Departments requiring specialized skills, like Technology, promote more to retain talent, especially in fast-changing industries.
#
# In essence, these factors—structure, metrics, resources, culture, and market demand—drive the significant association between department and promotion rates.

# %% [markdown]
# #### Part 2 : Region

# %%
region_promotion_summary = train_data.groupby('region')['is_promoted'].agg(
    Promotion_Rate='mean', 
    Number_of_Employees_Promoted='sum',
    Total_Employees='count'
).reset_index()

region_promotion_summary = region_promotion_summary.sort_values(by='Promotion_Rate', ascending=False)

region_promotion_summary
# Out:
#        region  Promotion_Rate  Number_of_Employees_Promoted  Total_Employees
# 28   region_4        0.144451                           246             1703
# 8   region_17        0.136935                           109              796
# 17  region_25        0.125763                           103              819
# 20  region_28        0.116844                           154             1318
# 15  region_23        0.116596                           137             1175
# 14  region_22        0.114188                           734             6428
# 22   region_3        0.106936                            37              346
# 31   region_7        0.106546                           516             4843
# 0    region_1        0.095082                            58              610
# 23  region_30        0.089802                            59              657
# 4   region_13        0.086858                           230             2648
# ...

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='region',hue='is_promoted',data=train_data)
plt.title('Region Promotion Distribution')
plt.xlabel('Region')
plt.ylabel('Employees')
plt.xticks(rotation=90) # so we can read x axis wordings
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='region', y='Promotion_Rate', data=region_promotion_summary, palette='viridis')
plt.title('Promotion Rate by Region')
plt.xlabel('region')
plt.ylabel('Promotion Rate')
plt.xticks(rotation=45)
plt.show()

# %%
contingency_table_region = pd.crosstab(train_data['is_promoted'], train_data['region'])

chi2_region, p_region, dof_region, expected_region = chi2_contingency(contingency_table_region)

print(f"Chi-Square Statistic: {chi2_region:.4f}")
print(f"P-Value: {p_region:.4f}")
print(f"Degrees of Freedom: {dof_region:.4f}")
# Out:
# Chi-Square Statistic: 475.6402
# P-Value: 0.0000
# Degrees of Freedom: 33.0000

# %% [markdown]
# A Chi-Square value of 475.6402 is quite high. This statistic measures the discrepancy between the observed frequencies (actual data) and the expected frequencies (what we would expect if there were no association between `region` and `is_promoted`).
# A higher Chi-Square value indicates a greater difference between the observed and expected frequencies, suggesting a stronger association between the variables.
#
# The p-value is effectively 0 (0.0000), which is significantly lower than the typical significance level of 0.05.
# This very low p-value indicates that the association between `region` and `is_promoted` is statistically significant. In other words, the likelihood that this association is due to random chance is extremely low.
#
#
# Degrees of freedom (33 in this case) relate to the number of categories in the `region` variable minus one, multiplied by the number of categories in the `is_promoted` variable minus one.
# This number affects the distribution of the Chi-Square statistic, and given the high Chi-Square value and the significant p-value, it further supports the conclusion that `region` plays an important role in determining promotion outcomes.
#
# **Real-World Implications :**
#
# - **Regional Influence**: The significant association suggests that the region where an employee works has a considerable impact on their likelihood of being promoted. This could be due to several factors, such as regional management practices, economic conditions, or differences in regional office cultures.
# - **HR and Organizational Strategy**: For the HR department, this insight could mean that certain regions might need more attention when it comes to balancing promotion opportunities. Regions with fewer promotions might need better resources, leadership training, or a reassessment of how promotions are handled.
# - **Employee Awareness**: Employees might perceive certain regions as offering better career advancement opportunities, which could influence decisions about relocations or transfers within the company.
#
# Understanding that region significantly affects promotions could lead to more focused analyses, such as:
# - Identifying specific regions with notably high or low promotion rates.
# - Investigating underlying reasons for these regional differences, like local leadership, resource allocation, or employee demographics.

# %% [markdown]
# #### Part 3 : Education

# %%
education_promotion_summary = train_data.groupby('education')['is_promoted'].agg(
    Promotion_Rate='mean', 
    Number_of_Employees_Promoted='sum',
    Total_Employees='count'
).reset_index()

education_promotion_summary = education_promotion_summary.sort_values(by='Promotion_Rate', ascending=False)

education_promotion_summary
# Out:
#           education  Promotion_Rate  Number_of_Employees_Promoted  \
# 2  Master's & above        0.098559                          1471
# 1   Below Secondary        0.083230                            67
# 0        Bachelor's        0.082031                          3008
# 3       unspecified        0.050643                           122
#
#    Total_Employees
# 2            14925
# 1              805
# 0            36669
# 3             2409

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='education',hue='is_promoted',data=train_data)
plt.title('Education Promotion Distribution')
plt.xlabel('Education Title')
plt.ylabel('Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='education', y='Promotion_Rate', data=education_promotion_summary, palette='viridis')
plt.title('Promotion Rate by Education Level')
plt.xlabel('Education Title')
plt.ylabel('Promotion Rate')
plt.xticks(rotation=45)
plt.show()

# %%
contingency_table_education = pd.crosstab(train_data['is_promoted'], train_data['education'])

chi2_education, p_education, dof_education, expected_education = chi2_contingency(contingency_table_education)

print(f"Chi-Square Statistic: {chi2_education:.4f}")
print(f"P-Value: {p_education:.4f}")
print(f"Degrees of Freedom: {dof_education:.4f}")
# Out:
# Chi-Square Statistic: 75.8734
# P-Value: 0.0000
# Degrees of Freedom: 3.0000

# %% [markdown]
# Given the degrees of freedom and the high Chi-Square statistic, the data strongly supports the conclusion that education level plays an important role in determining promotion likelihood.
#
# **Real-World Implications :**
#
# - **Educational Influence**: The significant association indicates that an employee's education level has a considerable impact on their chances of being promoted. Higher education levels might be associated with better promotion opportunities, possibly due to perceived higher competence, specialized skills, or better preparation for leadership roles.
#
# - **Organizational Policy**: For HR and management, this insight suggests that educational qualifications are a key factor in promotion decisions. This could lead to policies that emphasize continued education or the recruitment of employees with higher educational credentials.
#
# - **Employee Strategy**: Employees might be incentivized to pursue further education or certifications if they see a clear link between education level and career advancement within the organization.

# %% [markdown]
# #### Part 4 : Gender

# %%
gender_promotion_summary = train_data.groupby('gender')['is_promoted'].agg(
    Promotion_Rate='mean', 
    Number_of_Employees_Promoted='sum',
    Total_Employees='count'
).reset_index()

gender_promotion_summary = gender_promotion_summary.sort_values(by='Promotion_Rate', ascending=False)

gender_promotion_summary
# Out:
#   gender  Promotion_Rate  Number_of_Employees_Promoted  Total_Employees
# 0      f        0.089934                          1467            16312
# 1      m        0.083151                          3201            38496

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='gender',hue='is_promoted',data=train_data)
plt.title('Gender Promotion Distribution')
plt.xlabel('Gender')
plt.ylabel('Employees')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='gender', y='Promotion_Rate', data=gender_promotion_summary, palette='viridis')
plt.title('Promotion Rate by Gender')
plt.xlabel('gender')
plt.ylabel('Promotion_Rate')
plt.xticks(rotation=45)
plt.show()

# %%
contingency_table_gender = pd.crosstab(train_data['is_promoted'], train_data['gender'])

chi2_gender, p_gender, dof_gender, expected_gender = chi2_contingency(contingency_table_gender)

print(f"Chi-Square Statistic: {chi2_gender:.4f}")
print(f"P-Value: {p_gender:.4f}")
print(f"Degrees of Freedom: {dof_gender:.4f}")
# Out:
# Chi-Square Statistic: 6.6773
# P-Value: 0.0098
# Degrees of Freedom: 1.0000

# %% [markdown]
# With 1 degree of freedom, the result is significant enough to suggest a gender-based difference in promotion rates.
#
# **Real-World Implications :**
#
# - **Gender Influence**: The significant association indicates that gender does play a role in promotion decisions within the organization. However, the Chi-Square statistic and p-value suggest that while this relationship is significant, it may not be as strong as the associations seen with other factors like department or education.
#
# - **Organizational Policy**: These findings could lead HR and leadership teams to examine their promotion processes for potential biases. It might also prompt initiatives to ensure equitable promotion opportunities across genders.
#
# - **Employee Perception**: Employees might be aware of or perceive these gender differences in promotions, which could influence their satisfaction, engagement, and career planning within the organization.

# %% [markdown]
# #### Part 5 : Recruitment Channel

# %%
recruitment_promotion_summary = train_data.groupby('recruitment_channel')['is_promoted'].agg(
    Promotion_Rate='mean', 
    Number_of_Employees_Promoted='sum',
    Total_Employees='count'
).reset_index()

recruitment_promotion_summary = recruitment_promotion_summary.sort_values(by='Promotion_Rate', ascending=False)

recruitment_promotion_summary
# Out:
#   recruitment_channel  Promotion_Rate  Number_of_Employees_Promoted  \
# 1            referred        0.120841                           138
# 2            sourcing        0.085013                          1974
# 0               other        0.083952                          2556
#
#    Total_Employees
# 1             1142
# 2            23220
# 0            30446

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='recruitment_channel',hue='is_promoted',data=train_data)
plt.title('Channel Source Promotion Distribution')
plt.xlabel('Source')
plt.ylabel('Employees')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='recruitment_channel', y='Promotion_Rate', data=recruitment_promotion_summary, palette='viridis')
plt.title('Promotion Rate by Recruitment Channel')
plt.xlabel('Source')
plt.ylabel('Promotion Rate')
plt.show()

# %%
contingency_table_recruitment = pd.crosstab(train_data['is_promoted'], train_data['recruitment_channel'])

chi2_recruitment, p_recruitment, dof_recruitment, expected_recruitment = chi2_contingency(contingency_table_recruitment)

print(f"Chi-Square Statistic: {chi2_recruitment:.4f}")
print(f"P-Value: {p_recruitment:.4f}")
print(f"Degrees of Freedom: {dof_recruitment:.4f}")
# Out:
# Chi-Square Statistic: 19.2363
# P-Value: 0.0001
# Degrees of Freedom: 2.0000

# %% [markdown]
# The degrees of freedom here is 2, which corresponds to the number of categories in the `recruitment_channel` variable minus one.
# With 2 degrees of freedom, the significant result supports the conclusion that the recruitment channel plays an important role in determining promotion outcomes.
#
# **Real-World Implications :**
#
# - **Recruitment Channel Influence**: The significant association suggests that the method through which an employee was recruited has an impact on their promotion chances. This could be due to various factors, such as the type of candidates typically brought in through each channel, the perception of those candidates within the organization, or the alignment of recruitment channels with the company’s strategic needs.
#
# - **Organizational Policy**: For HR departments, this finding could lead to a closer examination of recruitment practices. If certain channels are consistently leading to higher promotion rates, the organization might focus more on those channels for future hiring, or alternatively, investigate why other channels are not performing as well.
#
# - **Employee Strategy**: Employees might become more aware of how their entry into the organization can influence their career trajectory. For example, being referred (which might be more closely associated with higher promotion rates) could be perceived as a better entry path compared to other channels.

# %% [markdown]
# #### **Summary of Categorical Analysis :**
#
# **1. Department**
#   - **Highest**: Technology (10.76%)
#   - **Lowest**: Procurement (9.64%)
#
# **Ranking (Best Bet for Promotions)**:
# 1. Technology (10.76%)
# 2. Procurement (9.64%)
# 3. Analytics (9.57%)
# 4. Operations (9.01%)
# 5. Finance (8.12%)
#
# **2. Region**
#   - **Highest**: Region_4 (14.45%)
#   - **Lowest**: Other regions with rates significantly lower (some around 7%).
#
# **Ranking (Best Bet for Promotions)**:
# 1. Region_4 (14.45%)
# 2. Region_17 (13.69%)
# 3. Region_25 (12.58%)
# 4. Region_28 (11.68%)
# 5. Region_23 (11.66%)
#
# **3. Education**
#   - **Highest**: Master's & above (9.86%)
#   - **Lowest**: Unspecified (5.06%)
#
# **Ranking (Best Bet for Promotions)**:
# 1. Master's & above (9.86%)
# 2. Below Secondary (8.32%)
# 3. Bachelor's (8.20%)
# 4. Unspecified (5.06%)
#
# **4. Gender**
# - **Promotion Rate Analysis**:
#   - **Highest**: Female (8.99%)
#   - **Lowest**: Male (8.31%)
#
# **5. Recruitment Channel**
# - **Promotion Rate Analysis**:
#   - **Highest**: Referred (12.08%)
#   - **Lowest**: Other (8.39%)
#
# **Overall Insights and Best Bets for Promotion**
# - **Best Department**: Technology
# - **Best Region**: Region_4
# - **Best Education Level**: Master’s & above
# - **Gender**: Females have a slight edge.
# - **Best Recruitment Channel**: Referred
#
# In summary, employees in the Technology department, especially those located in Region_4, with a Master’s degree or higher, and recruited through referrals, have the highest likelihood of being promoted. Females also have a slight edge over males in promotion rates, though the difference is minimal. This suggests that a combination of working in a strategic department and region, having advanced education, and leveraging referrals significantly enhances promotion prospects within the organization.

# %% [markdown]
# ### **3.2 Numerical Analysis**

# %% [markdown]
# Below are the features for numerical analysis :
#
# 1. **No of Trainings** (`no_of_trainings`)
# 2. **Age** (`age`)
# 3. **Previous Year Rating** (`previous_year_rating`)
# 4. **Length of Service** (`length_of_service`)
# 5. **Awards Won** (`awards_won?`)
# 6. **Avg Training Score** (`avg_training_score`)
#
# **Steps for Numerical Analysis :**
#
# 1. **Correlation Analysis**: We’ll look at the correlation between each numerical feature and the promotion status to see how these features relate to the likelihood of promotion.
# 2. **Visualizations**: We’ll use visual tools like box plots and scatter plots to observe the distributions and trends for each feature with respect to promotion status.
# 3. **Insights**: We’ll summarize the findings to understand which numerical factors are the most influential in determining promotion status.
#
# **Questions to Explore :**
#
# 1. Is there a correlation between each numerical feature and the promotion rate?
# 2. Does a higher value in these features increase the chances of getting promoted?

# %% [markdown]
# #### **Correlations of Numerical Features towards Target :**

# %%
numerical_features_with_target = ['is_promoted', 'no_of_trainings', 'age', 'previous_year_rating', 'length_of_service', 'avg_training_score', 'awards_won?']

# %%
# Calculate the correlation between numerical features and promotion status
correlations = train_data[numerical_features_with_target].corr()

correlations
# Out:
#                       is_promoted  no_of_trainings       age  \
# is_promoted              1.000000        -0.024896 -0.017166
# no_of_trainings         -0.024896         1.000000 -0.081278
# age                     -0.017166        -0.081278  1.000000
# previous_year_rating     0.125991        -0.064119  0.177935
# length_of_service       -0.010670        -0.057275  0.657111
# avg_training_score       0.181147         0.042517 -0.048380
# awards_won?              0.195871        -0.007628 -0.008169
#
#                       previous_year_rating  length_of_service  \
# is_promoted                       0.125991          -0.010670
# no_of_trainings                  -0.064119          -0.057275
# age                               0.177935           0.657111
# previous_year_rating              1.000000           0.191163
# length_of_service                 0.191163           1.000000
# avg_training_score                0.058718          -0.038122
# ...

# %% [markdown]
# Insights:
# - Avg Training Score and Previous Year Rating show a positive correlation with promotion status, suggesting that higher scores in these features are associated with a higher likelihood of promotion.
# - No of Trainings, Age, and Length of Service have slight negative correlations, indicating that these factors might not significantly impact promotion chances.
# -  Employees who have won awards are much more likely to be promoted than those who haven't. This suggests that awards serve as a significant indicator of an employee's readiness or qualification for promotion.

# %%
# Calculate the Spearman correlation matrix
spearman_corr = train_data[numerical_features_with_target].corr(method='spearman')

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Spearman Correlation Heatmap')
plt.show()

# %% [markdown]
# **Insights from the Spearman Correlation Heatmap:**
#
# The Spearman correlation heatmap reveals that the variables with the strongest positive correlations with being promoted are the `awards_won?` (0.20), `average_training_score` (0.16), and `previous_year_rating` (0.14). These factors are most associated with an increase in promotion likelihood, **but those scores are considered very low**.
#
# Other variables such as `age`, `number of trainings`, and `length of service` show little to no significant correlation with promotion, indicating that they are less to not influential at all in the promotion decision-making process within this dataset.
#
# `Age` has a moderate positive correlation with `length_of_service` (0.64). This is expected, as older employees typically have longer service durations. However, the correlation between `age` and promotion status is close to 0, suggesting that age is not a strong predictor of promotions.
#
# **Weak Overall Correlations :** Most numerical features have weak correlations with promotion status, suggesting that none of these variables are strong standalone predictors of whether an employee will be promoted.

# %%
from scipy.stats import mannwhitneyu

plt.figure(figsize=(20, 12), dpi=400)
plt.suptitle('Differences between Promoted and Non-Promoted Employees', fontsize=20)

# Iterate over each column and create a subplot
for i, column in enumerate(numerical_features, 1):
    plt.subplot(2, 3, i)
    ax = sns.boxplot(x='is_promoted', y=column, data=train_data, hue='is_promoted')
    
    # Perform Mann-Whitney U test
    promoted_data = train_data[train_data['is_promoted'] == 1][column]
    not_promoted_data = train_data[train_data['is_promoted'] == 0][column]
    u_stat, p_value = mannwhitneyu(promoted_data, not_promoted_data)
    
    # Annotate the plot with the Mann-Whitney U test results
    ax.text(0.5, 0.9, f'U-Statistic: {u_stat:.2f}\nP-Value: {p_value:.4f}', 
            ha='center', va='center', fontsize=10, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'),
            transform=ax.transAxes)
    
    ax.set_xticklabels(['Not Promoted', 'Promoted'], fontsize=12)
    plt.title(f'{column}', fontsize=14)
    plt.xlabel(None)
    plt.ylabel(None)
    if ax.legend_:
        ax.legend_.remove()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# **Key Insights from the Visualizations:**
#
# 1. **No of Trainings**:
#    - **Result**: Both groups have a similar distribution, with minimal differences.
#    - **Significance**: Statistically significant (p-value = 0.0000), but the actual impact is small.
#
# 2. **Age**:
#    - **Result**: Promoted employees tend to be slightly younger.
#    - **Significance**: Statistically significant (p-value = 0.0117), but the effect is mild.
#
# 3. **Previous Year Rating**:
#    - **Result**: Promoted employees generally have higher ratings.
#    - **Significance**: Strongly significant (p-value = 0.0000), indicating higher ratings are a key factor in promotions.
#
# 4. **Length of Service**:
#    - **Result**: Similar distribution between promoted and non-promoted employees.
#    - **Significance**: Not statistically significant (p-value = 0.2381), indicating tenure is not a major factor.
#
# 5. **Avg Training Score**:
#    - **Result**: Promoted employees have higher training scores.
#    - **Significance**: Strongly significant (p-value = 0.0000), suggesting higher scores are important for promotion.
#
# 6. **Awards Won**:
#    - **Result**: A clear difference, with promoted employees much more likely to have won awards.
#    - **Significance**: Strongly significant (p-value = 0.0000), making this a crucial factor in promotion decisions.
#
# **Conclusion:**
# - **Critical Factors**: `Previous Year Rating`, `Avg Training Score` and `Awards Won` are key drivers of promotion. Employees with higher ratings, better training scores, and awards are much more likely to be promoted.
# - **`Age`**: While not as influential as the top factors, younger employees have a statistically significant but modestly higher likelihood of being promoted.
# - **Less Impactful**: `No of Trainings` and `Length of Service` have minimal influence, while age shows a modest effect.
#
# These findings suggest that the organization prioritizes recent performance and training outcomes in promotion decisions.

# %%
# List of numerical features to test
columns_to_test = ['no_of_trainings', 'age', 'previous_year_rating', 
                   'length_of_service', 'avg_training_score','awards_won?']

results = []

# Perform Mann-Whitney U test for each feature
for column in columns_to_test:
    promoted = train_data[train_data['is_promoted'] == 1][column]
    not_promoted = train_data[train_data['is_promoted'] == 0][column]
    stat, p_value = mannwhitneyu(promoted, not_promoted)
    results.append({'Feature': column, 'Statistic': stat, 'p-value': p_value})

mann_result = pd.DataFrame(results).round(3)

mann_result['significant'] = mann_result['p-value'].map(lambda x: 'Significant' if x < 0.05 else 'Not Significant')

mann_result = mann_result.sort_values(by='p-value')

mann_result
# Out:
#                 Feature    Statistic  p-value      significant
# 0       no_of_trainings  113312788.5    0.000      Significant
# 2  previous_year_rating  148956236.0    0.000      Significant
# 4    avg_training_score  156778509.0    0.000      Significant
# 5           awards_won?  129381416.0    0.000      Significant
# 1                   age  114423048.5    0.012      Significant
# 3     length_of_service  115812965.5    0.238  Not Significant

# %% [markdown]
# **Why is `No of Trainings` Significant?**
#
# - **Statistical Significance vs Practical Significance**:
#   - **Statistical Significance**: The p-value for `no_of_trainings` is very low (0.000), which means that the difference in `no_of_trainings` between promoted and non-promoted employees is unlikely to be due to random chance. This is why it is marked as "Significant" in the table.
#   - **Practical Significance**: However, the actual difference in `no_of_trainings` between the two groups, as observed in the box plot, is very small. This means that while the difference is statistically significant, it might not be practically meaningful or impactful in a real-world context.
#
# **Conclusion:**
#
# - **No of Trainings**: Although the `no_of_trainings` feature is statistically significant, the difference between promoted and non-promoted employees is small. This suggests that while the number of trainings attended may have some influence on promotions, it is likely not a strong or decisive factor in practice.
#
# - **Overall**: This reinforces the idea that statistical significance doesn't always equate to practical importance. In the context of promotion decisions, other factors like `previous_year_rating`, `avg_training_score`, and `awards_won?` appear to have a more substantial and meaningful impact.

# %% [markdown]
# #### **Summary for Numerical Analysis :**
#
# The analysis suggests that the organization places a high value on recent performance (as indicated by ratings and training scores) and recognition (through awards) when making promotion decisions. Age also plays a role, though it is less influential. The number of trainings attended and tenure are less critical in determining who gets promoted.
#
# This summary provides a clear understanding of how numerical features affect promotion outcomes, helping to inform more data-driven HR decisions.

# %% [markdown]
# ### **3.3 Target Features :**

# %%
# Calculate the distribution of the target feature
target_distribution = train_data['is_promoted'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(target_distribution, labels=['Not Promoted', 'Promoted'], autopct='%1.1f%%', colors=['#ff9999','#66b3ff'])
plt.title('Distribution of Promotion Status')
plt.show()

# %% [markdown]
# The pie chart highlights a significant imbalance in the target variable `is_promoted`. With only a small percentage of employees being promoted, this imbalance is typical in organizational data, where promotions are often limited and selective.
#
# **Modeling Considerations :** The imbalance in the dataset suggests that when building predictive models, special techniques might be necessary to handle the imbalance effectively. For instance, we could use oversampling methods like SMOTE (Synthetic Minority Over-sampling Technique) to balance the classes, or we could adjust the model’s class weights to ensure that it doesn’t become biased towards predicting the majority class (Not Promoted).

# %% [markdown]
# ### **3.3 Final Takeway For EDA :**
#
# - **Critical Factors**:
#   - **Numerical**: `Previous Year Rating`, `Avg Training Score`, and `Awards Won` are the most significant factors influencing promotion. These metrics reflect both performance and recognition, which are key in promotion decisions.
#   - **Categorical**: `Region` has the most notable impact among categorical features, suggesting that location influences promotion likelihood. However, its impact is still moderate compared to the top numerical factors.
#
# - **Moderate Impact**:
#   - **Numerical**: `Age` has a modest influence, with younger employees slightly more likely to be promoted.
#   - **Categorical**: `Education` provides a slight edge in promotions, but it is not a decisive factor.
#
# - **Minimal Impact**:
#   - **Numerical**: `No of Trainings` shows statistical significance, but its practical impact is minimal. `Length of Service` is not significant.
#   - **Categorical**: `Department`, `Gender`, and `Recruitment Channel` have minimal direct influence on promotions.
#
# - **Target Feature Distribution**:
#   - The target feature `is_promoted` is highly imbalanced, with 91.5% of the employees not promoted and only 8.5% promoted. This significant imbalance suggests that the promotion process is highly selective, which could influence model performance. Special attention should be given to handling this imbalance during model training to avoid biases towards the majority class.
#
# The organization’s promotion decisions are most strongly influenced by performance-related factors (`Previous Year Rating`, `Avg Training Score`) and recognition through awards. While location and age play a role, they are less critical. Other factors like the number of trainings and categorical features like department and recruitment channel are less impactful in determining promotions.
#
# #### **Things To Consider In The Future :**
# - **Handling Imbalance** : Given the significant imbalance in the target feature, use techniques like resampling or adjusting class weights to ensure the model accurately predicts both promoted and non-promoted employees.

# %% [markdown]
# ## **4. Data Preparations and Preprocessing**

# %% [markdown]
# ### **4.1 Preparations and Feature Engineering**
#
# Before we continue to our preprocess and create pipelines, below are takeaways to note :
#
# - **Missing values**: There are 2 feature columns that has missing values. Namely, `previous_year_rating` and `education`. We have handled and fill in values for both features by adding the integer **0 (zero)** to missing `previous_year_rating` and adding string ***unspecified*** to missing `education`
# - **Duplicates**: There are no duplicates found on our dataset. Yet one thing to note, we need to remove the unique employee identifier (`employeeID`) as it would not mean anything nor contributes in the modeling process as it is merely just a replacement for said Index.
# - **Inconsistent values**: We have checked that there are no Categorical inconsistent values nor typos in our dataset.
# - **Outliers**: There are outliers in our dataset, namely `no_of_trainings` is 10430 or 19.03%, `age` is 1435 or 2.62% ,`length_of_service` is 3489 or 6.37% and `awards_won?` is 1270 or 2.32%
# - **Cardinality**: As previously mentioned on Chapter 2 in sub-chapter Cardinality and Rare Values, we found that `region` and `department` is concerning due to its high cardinality and the fact that rare values does exists on its features. We will finally handle it in this Chapter.
# - **Imbalance target**: As the comparison between Promoted and Not Promoted Employees in target variable `is_promoted` is 8.5 and 91.5, the distribution is highly imbalanced. While it is normal in real life, this moderately imbalanced distribution (see [Google for Developers, 2023](https://developers.google.com/machine-learning/data-prep/construct/sampling-splitting/imbalanced-data) for degrees of imbalance) issue will pose a bias challenge to the model, especially to the minority class. We will try a few experiments with diferrent Resampling Algorithm on **Chapter 5 Modelling**

# %%
X = train_data.drop(['is_promoted','employee_id'], axis=1)
y = train_data['is_promoted']

# split into train+val and test
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# split into train and val
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.1 ,stratify=y_train_val, random_state=42)

# %%
print("See each dataset shape")
print(f">> Training set : X : {X_train.shape} and y : {y_train.shape} and y proportion : \n{y_train.value_counts()}")
print(f">> Validation set : X : {X_val.shape} and y : {y_val.shape} and y proportion : \n{y_val.value_counts()}")
print(f">> Test set : X : {X_test.shape} and y : {y_test.shape} and y proportion : \n{y_test.value_counts()}")
# Out:
# See each dataset shape
# >> Training set : X : (44394, 11) and y : (44394,) and y proportion :
# 0    40613
# 1     3781
# Name: is_promoted, dtype: int64
# >> Validation set : X : (4933, 11) and y : (4933,) and y proportion :
# 0    4513
# 1     420
# Name: is_promoted, dtype: int64
# >> Test set : X : (5481, 11) and y : (5481,) and y proportion :
# 0    5014
# 1     467
# Name: is_promoted, dtype: int64

# %% [markdown]
# #### **Feature Engineering Archives**
#
# Thi is an unused section where we once tried, but at the end of modelling doesnt yield the best result.

# %% [markdown]
# #### Target Encoding

# %%
# #Target Encoding Department
# X_train['target'] = y_train
# target_mapper = X_train.groupby('department')['target'].mean().to_dict()

# %%
# #mapping to all datasets
# X_train['department_encoded'] = X_train['department'].map(target_mapper)
# X_val['department_encoded'] = X_val['department'].map(target_mapper)
# X_test['department_encoded'] = X_test['department'].map(target_mapper)

# %%
# X_train.drop('target',axis=1,inplace=True) #dropping temporary column

# %%
# # Department has been encoded so we can drop it

# X_train.drop('department',axis=1,inplace=True)
# X_val.drop('department',axis=1,inplace=True)
# X_test.drop('department',axis=1,inplace=True)

# %%
# #Target Encoding region
# X_train['target'] = y_train
# target_mapper = X_train.groupby('region')['target'].mean().to_dict()

# %%
# #mapping to all datasets
# X_train['region_encoded'] = X_train['region'].map(target_mapper)
# X_val['region_encoded'] = X_val['region'].map(target_mapper)
# X_test['region_encoded'] = X_test['region'].map(target_mapper)

# %%
# X_train.drop('target',axis=1,inplace=True) #dropping temporary column

# %%
# # Region has been encoded so we can drop it

# X_train.drop('region',axis=1,inplace=True)
# X_val.drop('region',axis=1,inplace=True)
# X_test.drop('region',axis=1,inplace=True)

# %%
# X_train

# %% [markdown]
# ### **4.2 Data Preprocess :**

# %% [markdown]
# #### **4.2.1 Scaling Numerical Features :**

# %% [markdown]
# **Comparison:**
# - **StandardScaler**: Sensitive to outliers; assumes normal distribution.
# - **MinMaxScaler**: Normalizes data to a fixed range but is outlier-sensitive.
# - **RobustScaler**: Scales data using the median and interquartile range (IQR)
#
# We choose Robust Scaler for our Scaler choice. And here is Why RobustScaler is Best:
#
# 1. **Outlier Resistance**:
#    - **RobustScaler** is less sensitive to outliers since it scales data using the median and interquartile range (IQR). This is crucial for our dataset, which likely contains outliers.
# 2. **Handles Skewed Data**:
#    - It’s ideal for datasets that aren't normally distributed, making it versatile for various types of data.
# 3. **Balanced Approach**:
#    - Provides a good balance between handling outliers and normalizing data without being influenced by extreme values.
#
# *RobustScaler* is the best choice given that our dataset has many outliers as it effectively handles outliers, ensuring that our features are scaled appropriately for most models.

# %% [markdown]
# #### **4.2.2 Encoding The Rest of Categoricals :**

# %% [markdown]
# We need to use **One Hot Encoder** to convert the rest of categoricals into Binary. because Machine Learning cannot read categoricals.

# %% [markdown]
# ### **4.3 Notable Experiments**
#
# This section shows what experiments we have done with preparation and prepocess before we finally decided to encode and scales. Below are unused codings that was once used until we decided to dispose of it due to it yielding lesser result than what we have obtained so far. **we only apply the binning regions here since it helps with our metric values by the end of modelling**.

# %% [markdown]
# #### Feature Selections Before Pipeline

# %%
# def tree_based_feature_importance(X_train,y_train):
#     from sklearn.ensemble import RandomForestClassifier
#     # create the random forest model
#     model = RandomForestClassifier()

#     # fit the model to start training.
#     model.fit(X_train, y_train)

#     # get the importance of the resulting features.
#     importances = model.feature_importances_

#     # create a data frame for visualization.
#     final_df = pd.DataFrame({"Features": X_train.columns, "Importances":importances})
#     final_df.set_index('Importances')

#     # sort in descending order 
#     final_df = final_df.sort_values('Importances',ascending=False)
    
#     #visualising feature importance
#     pd.Series(model.feature_importances_, index=X_train.columns).nlargest(6).plot(kind='barh')  
#     return final_df

# %%
# feature_importance=tree_based_feature_importance(X_train,y_train)

# %%
# display(feature_importance)

# %%
# # Making a list of selected features
# selected_features = ['avg_training_score','age',
#                      'length_of_service', 'region_encoded'
#                      'department_encoded','previous_year_rating','awards_won?',
#                      'no_of_trainings']
# X_train[selected_features]

# %%
# #Creating new datasets with just the selected features
# X_train=X_train[selected_features]
# X_val=X_val[selected_features]
# X_test=X_test[selected_features]

# %% [markdown]
# #### Winsorizing Outliers

# %%
# from scipy.stats.mstats import winsorize

# # specify cols to winsorize
# col_to_winsorize = ['Tenure', 'WarehouseToHome', 'HourSpendOnApp', 
#                     'NumberOfDeviceRegistered', 'NumberOfAddress', 
#                     'OrderAmountHikeFromlastYear', 'DaySinceLastOrder', 
#                     'OrderCount', 'CouponUsed',
#                     'CashbackAmount']  

# # create function to winsorize extreme values
# def apply_winsorization(df, columns, lower_limit=0.5, upper_limit=0.95):
#     df_winsorized = df.copy()  
    
#     for col in columns:
#         # apply winsorization to each column
#         df_winsorized[col] = winsorize(df[col], limits=[lower_limit, upper_limit])
    
#     return df_winsorized

# # perform winsorization
# winsorided_data = apply_winsorization(df.copy(), col_to_winsorize)

# # evaluate winsorization result
# for col in df[col_to_winsorize]:
#     detect_outliers(winsorided_data, col)

# %% [markdown]
# #### Binning Region

# %%
region_counts = train_data['region'].value_counts()

# Convert the frequency counts to a DataFrame for easier manipulation
region_counts_df = region_counts.reset_index()
region_counts_df.columns = ['region', 'count']

# Display the counts
print(region_counts_df)
# Out:
#        region  count
# 0    region_2  12343
# 1   region_22   6428
# 2    region_7   4843
# 3   region_15   2808
# 4   region_13   2648
# 5   region_26   2260
# 6   region_31   1935
# 7    region_4   1703
# 8   region_27   1659
# 9   region_16   1465
# 10  region_28   1318
# 11  region_11   1315
# 12  region_23   1175
# 13  region_29    994
# 14  region_32    945
# 15  region_19    874
# 16  region_20    850
# 17  region_14    827
# 18  region_25    819
# 19  region_17    796
# 20   region_5    766
# 21   region_6    690
# 22  region_30    657
# 23   region_8    655
# 24  region_10    648
# 25   region_1    610
# 26  region_24    508
# 27  region_12    500
# 28   region_9    420
# 29  region_21    411
# 30   region_3    346
# 31  region_34    292
# 32  region_33    269
# 33  region_18     31

# %%
# Calculate the percentage of each region
region_counts_df['percentage'] = region_counts_df['count'] / len(train_data) * 100

# Calculate the cumulative percentage
region_counts_df['cumulative_percentage'] = region_counts_df['percentage'].cumsum()

# Display the cumulative distribution
print(region_counts_df)
# Out:
#        region  count  percentage  cumulative_percentage
# 0    region_2  12343   22.520435              22.520435
# 1   region_22   6428   11.728215              34.248650
# 2    region_7   4843    8.836301              43.084951
# 3   region_15   2808    5.123340              48.208291
# 4   region_13   2648    4.831411              53.039702
# 5   region_26   2260    4.123486              57.163188
# 6   region_31   1935    3.530506              60.693694
# 7    region_4   1703    3.107211              63.800905
# 8   region_27   1659    3.026930              66.827835
# 9   region_16   1465    2.672967              69.500803
# 10  region_28   1318    2.404758              71.905561
# 11  region_11   1315    2.399285              74.304846
# 12  region_23   1175    2.143848              76.448694
# 13  region_29    994    1.813604              78.262297
# 14  region_32    945    1.724201              79.986498
# 15  region_19    874    1.594658              81.581156
# ...

# %%
# Plot the cumulative percentage
plt.figure(figsize=(10, 6))
plt.plot(region_counts_df['region'], region_counts_df['cumulative_percentage'], marker='o', linestyle='-', color='b')
plt.title('Cumulative Distribution of Region Feature')
plt.xlabel('Region')
plt.ylabel('Cumulative Percentage')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Calculate frequency distribution of the 'region' feature
region_counts = train_data['region'].value_counts().reset_index()
region_counts.columns = ['region', 'count']  # Ensure correct column names

# Calculate the percentage and cumulative percentage
region_counts['percentage'] = (region_counts['count'] / len(train_data)) * 100
region_counts['cumulative_percentage'] = region_counts['percentage'].cumsum()

# Create 5 bins based on the cumulative distribution
bins = pd.qcut(region_counts['cumulative_percentage'], q=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# Assign the bins to a new column in the region_counts DataFrame
region_counts['binned_region'] = bins

# Map the original regions to these bins in the original train_data DataFrame
region_binning_map = dict(zip(region_counts['region'], region_counts['binned_region']))
train_data['region_binned'] = train_data['region'].map(region_binning_map)

# Verify the new distribution
print(train_data['region_binned'].value_counts())
# Out:
# Very Low     33265
# Low           9629
# Medium        5111
# High          4534
# Very High     2269
# Name: region_binned, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='region_binned', data=train_data, order=train_data['region_binned'].value_counts().index)
plt.title('Distribution of Binned Regions')
plt.xlabel('Binned Region')
plt.ylabel('Count')
plt.show()

# %%
# Calculate the promotion rate for each binned region
promotion_rate_by_binned_region = train_data.groupby('region_binned')['is_promoted'].mean() * 100

# Convert the result to a DataFrame for easier plotting
promotion_rate_by_binned_region = promotion_rate_by_binned_region.reset_index()
promotion_rate_by_binned_region.columns = ['region_binned', 'promotion_rate']

# Display the promotion rates
print(promotion_rate_by_binned_region)
# Out:
#   region_binned  promotion_rate
# 0          High        6.749007
# 1           Low        9.211756
# 2        Medium        8.139307
# 3     Very High        5.068312
# 4      Very Low        8.850143

# %%
# Plot the promotion rate by binned region
plt.figure(figsize=(10, 6))
sns.barplot(x='region_binned', y='promotion_rate', data=promotion_rate_by_binned_region, palette='Blues_d')
plt.title('Promotion Rate by Binned Region')
plt.xlabel('Binned Region')
plt.ylabel('Promotion Rate (%)')
plt.ylim(0, promotion_rate_by_binned_region['promotion_rate'].max() + 1)  # Adjust the y-axis limit for better visualization
plt.show()

# %%
# Check the distribution of regions within each bin
region_counts_by_bin = train_data.groupby('region_binned')['region'].value_counts()

print(region_counts_by_bin)

# Summarize statistics of the target variable by binned region
summary_stats_by_bin = train_data.groupby('region_binned')['is_promoted'].describe()

print(summary_stats_by_bin)

plt.figure(figsize=(10, 6))
for bin_label in train_data['region_binned'].unique():
    subset = train_data[train_data['region_binned'] == bin_label]
    sns.kdeplot(subset['is_promoted'], label=f"{bin_label} Bin")
plt.title('Cumulative Distribution by Binned Region')
plt.xlabel('Target Variable')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# region_binned  region
# High           region_5       766
#                region_6       690
#                region_30      657
#                region_8       655
#                region_10      648
#                region_1       610
#                region_24      508
# Low            region_4      1703
#                region_27     1659
#                region_16     1465
#                region_28     1318
#                region_11     1315
#                region_23     1175
#                region_29      994
# Medium         region_32      945
#                region_19      874
#                region_20      850
#                region_14      827
#                region_25      819
#                region_17      796
# Very High      region_12      500
#                region_9       420
#                region_21      411
#                region_3       346
#                region_34      292
#                region_33      269
#                region_18       31
# ...

# %%
# Drop the original 'region' column
train_data.drop(columns=['region'], inplace=True)

train_data
# Out:
#        employee_id         department         education gender  \
# 0            65438  Sales & Marketing  Master's & above      f
# 1            65141         Operations        Bachelor's      m
# 2             7513  Sales & Marketing        Bachelor's      m
# 3             2542  Sales & Marketing        Bachelor's      m
# 4            48945         Technology        Bachelor's      m
# ...            ...                ...               ...    ...
# 54803         3030         Technology        Bachelor's      m
# 54804        74592         Operations  Master's & above      f
# 54805        13918          Analytics        Bachelor's      m
# 54806        13614  Sales & Marketing       unspecified      m
# 54807        51526                 HR        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# ...

# %% [markdown]
# #### Older Pipeline

# %%
# from sklearn.base import BaseEstimator, TransformerMixin
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import RobustScaler, OneHotEncoder, PowerTransformer
# from category_encoders import TargetEncoder

# # Create a custom transformer class for Winsorization
# class OutlierHandling(BaseEstimator, TransformerMixin):
#     def __init__(self, upper_limit=0.95, lower_limit=0.05):
#         self.upper_limit = upper_limit
#         self.lower_limit = lower_limit

#     def fit(self, X, y=None):
#         self.lower_bounds_ = np.percentile(X, self.lower_limit * 100, axis=0)
#         self.upper_bounds_ = np.percentile(X, self.upper_limit * 100, axis=0)
#         return self

#     def transform(self, X):
#         X = np.where(X < self.lower_bounds_, self.lower_bounds_, X)
#         X = np.where(X > self.upper_bounds_, self.upper_bounds_, X)
#         return X

# # Define numerical features to winsorize, scale, and normalize 
# num_features_to_winsor_scale = ['no_of_trainings', 'age', 'length_of_service', 'previous_year_rating', 'awards_won?', 'avg_training_score']

# # Create numerical transformer for winsorization, scaling, and normalization
# numerical_transformer = Pipeline(steps=[
#     ('winsor', OutlierHandling(upper_limit=0.90, lower_limit=0.05)),
#     ('scaling', RobustScaler()),
#     ('skew', PowerTransformer(method="yeo-johnson")) 
# ])

# # Define categorical features (except region)
# categorical_features_to_ohe = ['department', 'gender', 'recruitment_channel', 'education', 'region_binned']

# # Categorical transformer 1 for one-hot encoding
# categorical_transformer = Pipeline(steps=[
#     ('cat', OneHotEncoder(handle_unknown='ignore'))
# ])

# # Combine everything in a ColumnTransformer (example usage)
# from sklearn.compose import ColumnTransformer

# preprocessor = ColumnTransformer(
#     transformers=[
#         ('numerical preprocess', numerical_transformer, num_features_to_winsor_scale),
#         ('categorical OHE', categorical_transformer, categorical_features_to_ohe)
#     ]
# )

# preprocessor

# %% [markdown]
# ### **4.4 Creating Pipeline :**

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler


# Define numerical features to scale 
num_features_to_scale = ['no_of_trainings', 'age', 'length_of_service', 'previous_year_rating', 'awards_won?', 'avg_training_score']
categorical_to_ohe = ['education', 'recruitment_channel', 'gender', 'department']

# Create numerical transformer for winsorization, scaling, and normalization
numerical_transformer = Pipeline(steps=[
    ('scaling', RobustScaler()) 
])

# One hot transformer
categorical_transformer = Pipeline(steps=[
    ('one-hot', OneHotEncoder(handle_unknown='ignore'))
])

from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('numerical preprocess', numerical_transformer, num_features_to_scale),
        ('categorical OHE', categorical_transformer, categorical_to_ohe)
    ]
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('numerical preprocess',
#                                  Pipeline(steps=[('scaling', RobustScaler())]),
#                                  ['no_of_trainings', 'age', 'length_of_service',
#                                   'previous_year_rating', 'awards_won?',
#                                   'avg_training_score']),
#                                 ('categorical OHE',
#                                  Pipeline(steps=[('one-hot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['education', 'recruitment_channel', 'gender',
#                                   'department'])])

# %%
print(f"Length of X_train: {len(X_train)}")
print(f"Length of y_train: {len(y_train)}")
# Out:
# Length of X_train: 44394
# Length of y_train: 44394

# %% [markdown]
# ## **5. Modelling Experiments :**

# %% [markdown]
# #### 5.1 Model Benchmarking (K-Fold)

# %% [markdown]
# This code evaluates multiple machine learning models on a given dataset using stratified cross-validation. It uses several classifiers and evaluates them based on the ROC AUC score and the F2 score. The results are then compiled into a DataFrame for easy comparison.
#
# **Cross-Validation**
#
# 1. **Stratified K-Fold Cross-Validation**: This ensures that each fold has the same proportion of class labels, which is important for imbalanced datasets.
# 2. **Imbalanced Pipeline**: An imbalanced-learn pipeline `ImbPipeline` is created with the preprocessing step and the current model.
# 3. **Cross-Validation**: The `cross_validate` function evaluates the model using the pipeline and the stratified folds, scoring based on ROC AUC and F2 score. The results are stored in the lists.
#
# **What This Code Achieves**
# - **Comparative Analysis**: It allows you to compare multiple models based on their performance metrics.
# - **Model Selection**: Helps in selecting the best model based on the F2 score, which emphasizes recall more than precision (useful for imbalanced datasets).
# - **Cross-Validation**: Provides a robust evaluation by using stratified K-fold cross-validation, ensuring that performance estimates are reliable and not biased due to data splitting.

# %%
from sklearn.model_selection import cross_validate
from xgboost import XGBClassifier


logreg = LogisticRegression(random_state=42)
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
gb = GradientBoostingClassifier(random_state=42)
xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
lgbm = LGBMClassifier(random_state=42,verbose=-100)


models = [logreg, knn, dt, rf, xgb, lgbm, gb]
model_names = ['Logistic Regression', 'KNN', 'Decision Tree', 'Random Forest', 'XGBoost', 'LightGBM', 'Gradient Boosting']

roc_auc_scores = []
f2_scores = []
mean_roc_aucs = []
mean_f2s = []
std_roc_aucs = []
std_f2s = []

# Custom F2 scorer
f2_scorer = make_scorer(fbeta_score, beta=2)

# Evaluate each model using StratifiedKFold cross-validation
for model in models:
    skfold = StratifiedKFold(n_splits=5)
    estimator = ImbPipeline([
        ('preprocess', preprocessor),
        ('model', model)
    ])
    
    scores = cross_validate(estimator, X_train, y_train, cv=skfold, scoring={'roc_auc': 'roc_auc', 'f2': f2_scorer})
    roc_auc_scores.append(scores['test_roc_auc'])
    f2_scores.append(scores['test_f2'])
    mean_roc_aucs.append(scores['test_roc_auc'].mean())
    mean_f2s.append(scores['test_f2'].mean())
    std_roc_aucs.append(scores['test_roc_auc'].std())
    std_f2s.append(scores['test_f2'].std())

results_df_kfold = pd.DataFrame({
    'Model': model_names,
    'Mean ROC AUC': mean_roc_aucs,
    'ROC AUC Std Dev': std_roc_aucs,
    'Mean F2 Score': mean_f2s,
    'F2 Score Std Dev': std_f2s
})

# Sort the results by mean F2 Score in descending order
results_df_sorted_kfold = results_df_kfold.set_index('Model').sort_values(by='Mean F2 Score', ascending=False)

results_df_sorted_kfold
# Out:
#                      Mean ROC AUC  ROC AUC Std Dev  Mean F2 Score  \
# Model
# XGBoost                  0.798034         0.004331       0.399360
# LightGBM                 0.806340         0.003200       0.395207
# Decision Tree            0.668449         0.008925       0.392117
# Gradient Boosting        0.807286         0.005424       0.376438
# Random Forest            0.754174         0.006770       0.368633
# Logistic Regression      0.764147         0.009189       0.324126
# KNN                      0.657313         0.008084       0.156855
#
#                      F2 Score Std Dev
# Model
# XGBoost                      0.013756
# LightGBM                     0.014600
# Decision Tree                0.017060
# Gradient Boosting            0.010594
# Random Forest                0.010327
# Logistic Regression          0.007750
# KNN                          0.007811

# %% [markdown]
# From the perspective of default Hyperparameter, **XGBoost** and **LightGBM** won the comparations from `F2` score. Let's move on to the next step.

# %% [markdown]
# #### 5.2 Model Benchmarking (Data Test)

# %% [markdown]
# This code trains each pipeline, evaluates its performance, and determines the best model based on the F2 score. This code performs similar tasks to the previous one but with some differences. Below are the difference compares to the previous code:
#
# - **Cross-Validation**: The previous code uses stratified K-fold cross-validation to evaluate models, while the current code splits the data into a single training and test set.
# - **Evaluation Function**: The current code uses a function `train_and_evaluate` to encapsulate the training and evaluation logic for each model, while the previous code uses `cross_validate`.
#
# **Summary**
# - The current code is more streamlined and focuses on evaluating models on a single train/test split using pipelines, which include preprocessing steps. It does not use cross-validation, making it potentially faster but less robust compared to the previous code.
# - The previous code is more rigorous with cross-validation, providing more reliable performance estimates but at the cost of increased computational time.

# %%
def train_and_evaluate(model, model_name):
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    
    # Calculate F2 score
    f2 = fbeta_score(y_test, y_pred, beta=2)
    
    # Calculate ROC AUC score
    if hasattr(model, "predict_proba"):
        y_prob = pipeline.predict_proba(X_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_prob)
    else:
        roc_auc = "N/A"  # Some models might not have predict_proba method
    
    print(f"{model_name} Report:\n", report)
    print(f"F2 Score: {f2}")
    print(f"ROC AUC Score: {roc_auc}")
    
    return model_name, accuracy, report, f2, roc_auc

# Define models to evaluate
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": LGBMClassifier(random_state=42,verbose=-100),
    "K-Nearest Neighbors": KNeighborsClassifier(),

}

# Train and evaluate each model
results = []
for model_name, model in models.items():
    result = train_and_evaluate(model, model_name)
    results.append(result)

# Determine the best model based on F2
best_model_traintest = max(results, key=lambda item: item[3])
best_model_name, best_model_accuracy, best_model_report, best_model_f2, best_model_roc_auc = best_model_traintest

print(f"Best Model: {best_model_name}")
print(f"Accuracy: {best_model_accuracy}")
print(f"Classification Report:\n{best_model_report}")
print(f"F2 Score: {best_model_f2}")
print(f"ROC AUC Score: {best_model_roc_auc}")
# Out:
# Logistic Regression Report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5014
#            1       0.95      0.27      0.42       467
#
#     accuracy                           0.94      5481
#    macro avg       0.94      0.63      0.69      5481
# weighted avg       0.94      0.94      0.92      5481
#
# F2 Score: 0.3125
# ROC AUC Score: 0.7594305537642352
# Decision Tree Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      5014
#            1       0.34      0.40      0.37       467
#
#     accuracy                           0.88      5481
#    macro avg       0.64      0.66      0.65      5481
# weighted avg       0.89      0.88      0.89      5481
#
# F2 Score: 0.3844563869367507
# ROC AUC Score: 0.6624150451540824
# Random Forest Report:
#                precision    recall  f1-score   support
#
# ...

# %%
columns = ["Model", "Accuracy", "Classification Report", "F2 Score", "ROC AUC Score"]
df_results_bmtraintest = pd.DataFrame(results, columns=columns)

best_model_traintest = df_results_bmtraintest[df_results_bmtraintest['F2 Score'] == df_results_bmtraintest['F2 Score'].max()]
print("\nBest Model based on F2 Score:")
print(best_model_traintest)

df_sorted_bmtraintest = df_results_bmtraintest.drop(columns='Classification Report').sort_values(by='F2 Score', ascending=False)
df_sorted_bmtraintest
# Out:
# Best Model based on F2 Score:
#       Model  Accuracy                              Classification Report  \
# 5  LightGBM  0.941069                precision    recall  f1-score   ...
#
#    F2 Score  ROC AUC Score
# 5  0.389324       0.792298
#                  Model  Accuracy  F2 Score  ROC AUC Score
# 5             LightGBM  0.941069  0.389324       0.792298
# 4              XGBoost  0.941434  0.387635       0.786538
# 1        Decision Tree  0.882138  0.384456       0.662415
# 3    Gradient Boosting  0.939974  0.361029       0.796413
# 2        Random Forest  0.928480  0.354236       0.743934
# 0  Logistic Regression  0.936325  0.312500       0.759431
# 6  K-Nearest Neighbors  0.918263  0.125835       0.634685

# %% [markdown]
# Again, **LightGBM** and **XGBoost** is the ideal model in terms of `F2 Score` which is crucial for our business problem since our `False Negative` has **5x bigger** impact than `False Positive`. Also, the `ROC AUC` score at 78-79% reflects that it is optimal and sufficient for differentiating and recognizing between classes.

# %% [markdown]
# ### **5.3 Resampling Experiments**

# %% [markdown]
# We consider oversampling knowing that our data target is imbalance. Oversampling could help the model to yield better results

# %% [markdown]
# **source :** https://stackoverflow.com/questions/44244711/imbalanced-data-undersampling-or-oversampling

# %% [markdown]
# #### Before Resampling

# %%
# Initialize the model with default parameters
model_lgbm = LGBMClassifier(random_state=42,verbose=-100)

clf_lgbm_default = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', model_lgbm)
])

clf_lgbm_default.fit(X_train, y_train)

y_pred_lgbm_default = clf_lgbm_default.predict(X_test)
y_prob__lgbm_default = clf_lgbm_default.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_lgbm_default))

f2 = fbeta_score(y_test, y_pred_lgbm_default, beta=2)
print(f"F2 Score: {f2}")

roc_auc = roc_auc_score(y_test, y_prob__lgbm_default)
print(f"ROC AUC: {roc_auc}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5014
#            1       0.91      0.34      0.50       467
#
#     accuracy                           0.94      5481
#    macro avg       0.93      0.67      0.73      5481
# weighted avg       0.94      0.94      0.93      5481
#
# F2 Score: 0.3893241919686582
# ROC AUC: 0.7922978401375508

# %%
# Initialize the model with default parameters
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss')

clf_xgb = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_model)
])

clf_xgb.fit(X_train, y_train)

y_pred_xgb = clf_xgb.predict(X_test)
y_prob__xgb = clf_xgb.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_xgb))

f2 = fbeta_score(y_test, y_pred_xgb, beta=2)
print(f"F2 Score: {f2}")

roc_auc = roc_auc_score(y_test, y_prob__xgb)
print(f"ROC AUC: {roc_auc}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5014
#            1       0.93      0.34      0.50       467
#
#     accuracy                           0.94      5481
#    macro avg       0.94      0.67      0.73      5481
# weighted avg       0.94      0.94      0.93      5481
#
# F2 Score: 0.38763493621197254
# ROC AUC: 0.7865377371624974

# %% [markdown]
# #### Start Resampling

# %% [markdown]
# #### **LightGBM**

# %%
# We change class weight param to Balanced
model_lgbm = LGBMClassifier(random_state=42, class_weight='balanced',verbose=-100)

# Resampling methods
resampling_methods = {
    'ADASYN': ADASYN(random_state=42),
    'SMOTE': SMOTE(random_state=42),
    'SMOTEENN': SMOTEENN(random_state=42)
}

def evaluate_model(resampler_name, resampler):
    clf = ImbPipeline(steps=[
        ('preprocessor', preprocessor),
        ('resampler', resampler),
        ('classifier', model_lgbm)
    ])

    clf.fit(X_train, y_train)
    y_pred_lgbm_resample = clf.predict(X_test)
    y_prob_lgbm_resample = clf.predict_proba(X_test)[:, 1]

    f2 = fbeta_score(y_test, y_pred_lgbm_resample, beta=2)
    roc_auc = roc_auc_score(y_test, y_prob_lgbm_resample)

    print(f"{resampler_name} Resampling")
    print(classification_report(y_test, y_pred_lgbm_resample))
    print(f"F2 Score: {f2}")
    print(f"ROC AUC: {roc_auc}")

    return resampler_name, f2, roc_auc

# Evaluate models with different resampling methods
results = []
for name, resampler in resampling_methods.items():
    result = evaluate_model(name, resampler)
    results.append(result)

results_df_lgbm_resample = pd.DataFrame(results, columns=['Resampling Method', 'F2 Score', 'ROC AUC'])
results_df_sorted_lgbm_resample = results_df_lgbm_resample.sort_values(by='F2 Score', ascending=False)

print("\nComparison of Resampling Methods:")
results_df_sorted_lgbm_resample
# Out:
# ADASYN Resampling
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5014
#            1       0.87      0.34      0.49       467
#
#     accuracy                           0.94      5481
#    macro avg       0.90      0.67      0.73      5481
# weighted avg       0.94      0.94      0.93      5481
#
# F2 Score: 0.3853658536585366
# ROC AUC: 0.7826388040680954
# SMOTE Resampling
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5014
#            1       0.84      0.34      0.48       467
#
#     accuracy                           0.94      5481
#    macro avg       0.89      0.67      0.72      5481
# weighted avg       0.93      0.94      0.93      5481
#
# F2 Score: 0.3840544482255712
# ROC AUC: 0.7838155947074101
# SMOTEENN Resampling
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      5014
# ...

# %% [markdown]
# #### **XGBoost**

# %%
# We change class weight param to Balanced
xgb_model_bal = XGBClassifier(random_state=42, class_weight='balanced', use_label_encoder=False, eval_metric='logloss')

# Resampling methods
resampling_methods = {
    'ADASYN': ADASYN(random_state=42),
    'SMOTE': SMOTE(random_state=42),
    'SMOTEENN': SMOTEENN(random_state=42)
}

def evaluate_model(resampler_name, resampler):
    clf = ImbPipeline(steps=[
        ('preprocessor', preprocessor),
        ('resampler', resampler),
        ('classifier', xgb_model_bal)
    ])

    clf.fit(X_train, y_train)
    y_pred_xgb_model_resample = clf.predict(X_test)
    y_prob_xgb_model_resample = clf.predict_proba(X_test)[:, 1]

    f2 = fbeta_score(y_test, y_pred_xgb_model_resample, beta=2)
    roc_auc = roc_auc_score(y_test, y_prob_xgb_model_resample)

    print(f"{resampler_name} Resampling")
    print(classification_report(y_test, y_pred_xgb_model_resample))
    print(f"F2 Score: {f2}")
    print(f"ROC AUC: {roc_auc}")

    return resampler_name, f2, roc_auc

# Evaluate models with different resampling methods
results = []
for name, resampler in resampling_methods.items():
    result = evaluate_model(name, resampler)
    results.append(result)

results_df_xgb_resample = pd.DataFrame(results, columns=['Resampling Method', 'F2 Score', 'ROC AUC'])
results_df_sorted_xgb_resample = results_df_xgb_resample.sort_values(by='F2 Score', ascending=False)

print("\nComparison of Resampling Methods:")
results_df_sorted_xgb_resample
# Out:
# ADASYN Resampling
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5014
#            1       0.86      0.33      0.48       467
#
#     accuracy                           0.94      5481
#    macro avg       0.90      0.66      0.72      5481
# weighted avg       0.93      0.94      0.93      5481
#
# F2 Score: 0.3804878048780488
# ROC AUC: 0.7756128664151511
# SMOTE Resampling
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      5014
#            1       0.84      0.35      0.50       467
#
#     accuracy                           0.94      5481
#    macro avg       0.89      0.67      0.73      5481
# weighted avg       0.93      0.94      0.93      5481
#
# F2 Score: 0.3997093023255814
# ROC AUC: 0.7737356814196481
# SMOTEENN Resampling
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      5014
# ...

# %% [markdown]
# The best Resampling method would be using **SMOTEENN** based from both our experiment result with **LightGBM** won by 0.01 points from **XGBoost**. Now let's get to the final step which is Hyperparameter Tuning

# %% [markdown]
# ### **5.4 Hyperparameter Tuning Experiment**

# %% [markdown]
# In this section, we will apply Hyperparameter Tuning for **LightGBM** and **XGboost** with `RandomizedSearchCV` to see which result would give best classification report.

# %% [markdown]
# #### **XGBoost**

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.combine import SMOTEENN


xgb_model_bal = XGBClassifier(random_state=42, class_weight='balanced', use_label_encoder=False, eval_metric='logloss')


f2_scorer = make_scorer(fbeta_score, beta=2)

# Define the reduced hyperparameters grid
param_dist = {
    'classifier__n_estimators': [100, 300, 500],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.05, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
}

# Define the pipeline
clf_xgb_hyp = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('resampler', SMOTEENN(random_state=42)),
    ('classifier', xgb_model_bal )
])

# Set up the RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=clf_xgb_hyp,
    param_distributions=param_dist,
    n_iter=20,  # Reduced number of parameter settings sampled
    scoring=f2_scorer,  
    n_jobs=-1,
    cv=5,  # 5-fold cross-validation
    verbose=3,
    random_state=42
)

# Fit the random search model
random_search.fit(X_train, y_train)

# Get the best parameters and score
best_params = random_search.best_params_
best_f2 = random_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best F2 Score: {best_f2}")

# Predict on the test set using the best model
best_model_xgb_hyp = random_search.best_estimator_
y_pred_best_model_xgb_hyp = best_model_xgb_hyp.predict(X_test)
y_prob_best_model_xgb_hyp = best_model_xgb_hyp.predict_proba(X_test)[:, 1]

# Evaluate the best model on the test set
f2_best_model = fbeta_score(y_test, y_pred_best_model_xgb_hyp, beta=2)
roc_auc_best_model = roc_auc_score(y_test, y_prob_best_model_xgb_hyp)

print("\nBest Model Performance on Test Set:")
print(classification_report(y_test, y_pred_best_model_xgb_hyp))
print(f"F2 Score: {f2_best_model}")
print(f"ROC AUC: {roc_auc_best_model}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'classifier__subsample': 0.8, 'classifier__n_estimators': 100, 'classifier__max_depth': 5, 'classifier__learning_rate': 0.05}
# Best F2 Score: 0.4736876602426713
#
# Best Model Performance on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      5014
#            1       0.28      0.55      0.37       467
#
#     accuracy                           0.84      5481
#    macro avg       0.62      0.71      0.64      5481
# weighted avg       0.90      0.84      0.86      5481
#
# F2 Score: 0.46322999279019467
# ROC AUC: 0.7762707673332656

# %% [markdown]
# #### **LightGBM**

# %%
import lightgbm as lgb
from sklearn.model_selection import RandomizedSearchCV
from imblearn.pipeline import Pipeline as ImbPipeline

# Define the LightGBM model
lgb_model_hyp = lgb.LGBMClassifier(random_state=42, class_weight='balanced', verbose=-100)

# Define the hyperparameter grid for tuning
param_dist = {
    'classifier__n_estimators': [100, 300, 500],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.05, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
}

# Create the pipeline
pipeline = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('resampler', SMOTEENN(random_state=42)),  
    ('classifier', lgb_model_hyp)
])

# Define the custom F2 scorer
f2_scorer = make_scorer(fbeta_score, beta=2)

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_dist,
    n_iter=20,  # Number of different combinations to try
    scoring=f2_scorer,  # Optimize for F2 score
    n_jobs=-1,
    cv=5,  # 5-fold cross-validation
    verbose=3,
    random_state=42
)

# Fit the RandomizedSearchCV model
random_search.fit(X_train, y_train)

# Get the best parameters and the best F2 score
best_params = random_search.best_params_
best_f2 = random_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best F2 Score: {best_f2}")

# Predict on the test set using the best model
best_model_lgb_hyp = random_search.best_estimator_
y_pred_best_model_lgb_hyp = best_model_lgb_hyp.predict(X_test)
y_prob_best_model_lgb_hyp = best_model_lgb_hyp.predict_proba(X_test)[:, 1]

# Evaluate the best model on the test set
f2_best_model = fbeta_score(y_test, y_pred_best_model_lgb_hyp, beta=2)
roc_auc_best_model = roc_auc_score(y_test, y_prob_best_model_lgb_hyp)

print("\nBest Model Performance on Test Set:")
print(classification_report(y_test, y_pred_best_model_lgb_hyp))
print(f"F2 Score: {f2_best_model}")
print(f"ROC AUC: {roc_auc_best_model}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'classifier__subsample': 0.8, 'classifier__n_estimators': 100, 'classifier__max_depth': 3, 'classifier__learning_rate': 0.1}
# Best F2 Score: 0.4689795125814956
#
# Best Model Performance on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92      5014
#            1       0.30      0.52      0.38       467
#
#     accuracy                           0.86      5481
#    macro avg       0.63      0.70      0.65      5481
# weighted avg       0.90      0.86      0.87      5481
#
# F2 Score: 0.453696788648245
# ROC AUC: 0.7719676127400025

# %% [markdown]
# #### **XGBoost with more Parameter Dist.**

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.combine import SMOTEENN

f2_scorer = make_scorer(fbeta_score, beta=2)

# Define the reduced hyperparameters grid
param_dist = {
    'classifier__n_estimators': [100, 300, 500],
    'classifier__max_depth': [3, 5, 7],
    'classifier__learning_rate': [0.05, 0.1, 0.2],
    'classifier__subsample': [0.7, 0.8, 1.0],
    'classifier__scale_pos_weight': [20],  # Adjusted weight for class 1
    'classifier__colsample_bytree': [0.6, 0.8, 1.0]  # Added colsample_bytree
}

# Define the pipeline
clf_xgb_hyp2 = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('resampler', SMOTEENN(random_state=42)),
    ('classifier', XGBClassifier(random_state=42, use_label_encoder=False, eval_metric='logloss'))
])

# Set up the RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=clf_xgb_hyp2,
    param_distributions=param_dist,
    n_iter=20,  # Reduced number of parameter settings sampled
    scoring=f2_scorer,  
    n_jobs=-1,
    cv=5,  # 5-fold cross-validation
    verbose=3,
    random_state=42
)

# Fit the random search model
random_search.fit(X_train, y_train)

# Get the best parameters and score
best_params_xgb2 = random_search.best_params_
best_f2 = random_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best F2 Score: {best_f2}")

# Predict on the test set using the best model
best_model_xgb_hyp2 = random_search.best_estimator_
y_pred_best_model_xgb_hyp2 = best_model_xgb_hyp2.predict(X_test)
y_prob_best_model_xgb_hyp2 = best_model_xgb_hyp2.predict_proba(X_test)[:, 1]

# Evaluate the best model on the test set
f2_best_model = fbeta_score(y_test, y_pred_best_model_xgb_hyp2, beta=2)
roc_auc_best_model = roc_auc_score(y_test, y_prob_best_model_xgb_hyp2)

print("\nBest Model Performance on Test Set:")
print(classification_report(y_test, y_pred_best_model_xgb_hyp2))
print(f"F2 Score: {f2_best_model}")
print(f"ROC AUC: {roc_auc_best_model}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'classifier__subsample': 0.8, 'classifier__n_estimators': 100, 'classifier__max_depth': 5, 'classifier__learning_rate': 0.05}
# Best F2 Score: 0.4545019298352114
#
# Best Model Performance on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.75      0.84     10028
#            1       0.19      0.64      0.29       934
#
#     accuracy                           0.74     10962
#    macro avg       0.57      0.69      0.57     10962
# weighted avg       0.89      0.74      0.79     10962
#
# F2 Score: 0.4332313965341488
# ROC AUC: 0.7764933240459903

# %% [markdown]
# Nothing much comes out from modifying the parameter grids with a few different methods using **XGboost**. This leads us to a conclusion where **XGBoost** from the first attempt of Hyperparametric Tuning as the winner model for now.

# %% [markdown]
# #### **Report and Confusion Metric :**

# %%
print(classification_report(y_test, y_pred_best_model_xgb_hyp))

f2 = fbeta_score(y_test, y_pred_best_model_xgb_hyp, beta=2)
print(f"F2 Score: {f2}")

roc_auc = roc_auc_score(y_test, y_prob_best_model_xgb_hyp)
print(f"ROC AUC: {roc_auc}")

cmlgbmada = confusion_matrix(y_test, y_pred_best_model_xgb_hyp)
print(cmlgbmada)

ax= plt.subplot()
sns.heatmap(cmlgbmada, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      5014
#            1       0.28      0.55      0.37       467
#
#     accuracy                           0.84      5481
#    macro avg       0.62      0.71      0.64      5481
# weighted avg       0.90      0.84      0.86      5481
#
# F2 Score: 0.46322999279019467
# ROC AUC: 0.7762707673332656
# [[4365  649]
#  [ 210  257]]

# %% [markdown]
# **False Positive (FP) :** **1200** USD per employee
#
# **False Negative (FN) :** 4700 + 1200 = **5900** USD per employee
#
#
# Confusion Matrix:
#
# |              | Predicted Negative | Predicted Positive |
# |--------------|--------------------|--------------------|
# | Actual Negative |         4365     |         649         |
# | Actual Positive |          210        |        257         |
#
#
# 1. **Loss due to False Positives (Type 1 Error):**
#    - False Positives (FP) = 649
#    - Loss Type 1 = FP * Cost per False Positive
#    - Loss Type 1 = 649 * $1200 = $778,800
#
# 2. **Loss due to False Negatives (Type 2 Error):**
#    - False Negatives (FN) = 210
#    - Loss Type 2 = FN * Cost per False Negative
#    - Loss Type 2 = 210 * $5900 = $1,239,000
#
# 3. **Total Loss:**
#    - Total Loss = Loss Type 1 + Loss Type 2
#    - Total Loss = $778,800 + $1,239,000 = $2,017,800
#
# **False Negative Rate:**
# FNR = 210 / 210 + 257 = 44.97 %
# 467
#
# So, the company's total loss from the given confusion matrix is **$2,017,800** with  **44.97 % FNR**

# %% [markdown]
# ## **6. Final Model Evaluation**

# %% [markdown]
# ### 6.1 Calibration
#
# Calibration adjusts the predicted probabilities of a classifier to better reflect the true probabilities. This is important for applications where accurate probability estimates are crucial.

# %% [markdown]
# #### 6.1.1 Before Calibration

# %%
# Generate the calibration curve data
prob_true, prob_pred = calibration_curve(y_test, y_prob_best_model_xgb_hyp, n_bins=10)

plt.figure(figsize=(10, 7))
plt.plot(prob_pred, prob_true, marker='o', linewidth=1, label='LightGBM')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfectly calibrated')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction of positives')
plt.title('Calibration plot (reliability curve)')
plt.legend()
plt.show()

# %% [markdown]
# #### 6.1.2 After Calibration

# %%
# Calibrate the model using Platt Scaling
best_model_xgb_hyp_cal = CalibratedClassifierCV(best_model_xgb_hyp, method='sigmoid', cv='prefit')
best_model_xgb_hyp_cal.fit(X_train, y_train)

# Generate new predicted probabilities
y_prob_calibrated = best_model_xgb_hyp_cal.predict_proba(X_test)[:, 1]

prob_true_calibrated, prob_pred_calibrated = calibration_curve(y_test, y_prob_calibrated, n_bins=10)

plt.figure(figsize=(10, 7))
plt.plot(prob_pred_calibrated, prob_true_calibrated, marker='o', linewidth=1, label='Calibrated LightGBM')
plt.plot([0, 1], [0, 1], linestyle='--', label='Perfectly calibrated')
plt.xlabel('Mean predicted probability')
plt.ylabel('Fraction of positives')
plt.title('Calibration plot (reliability curve) after calibration')
plt.legend()
plt.show()

# Make predictions with the model
y_pred_xgb_hyp_cal = best_model_xgb_hyp_cal.predict(X_test)
y_prob_xgb_hyp_cal = best_model_xgb_hyp_cal.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_xgb))
f2 = fbeta_score(y_test, y_pred_xgb_hyp_cal, beta=2)
print(f"F2 Score: {f2}")
roc_auc = roc_auc_score(y_test, y_prob_xgb_hyp_cal)
print(f"ROC AUC: {roc_auc}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      5014
#            1       0.93      0.34      0.50       467
#
#     accuracy                           0.94      5481
#    macro avg       0.94      0.67      0.73      5481
# weighted avg       0.94      0.94      0.93      5481
#
# F2 Score: 0.2501263264274886
# ROC AUC: 0.7762707673332656

# %% [markdown]
# **Comparations to Non-Calibrated Final Model Report**

# %%
print(classification_report(y_test, y_pred_best_model_xgb_hyp))
f2 = fbeta_score(y_test, y_pred_best_model_xgb_hyp, beta=2)
print(f"F2 Score: {f2}")
roc_auc = roc_auc_score(y_test, y_prob_best_model_lgb_hyp)
print(f"ROC AUC: {roc_auc}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      5014
#            1       0.28      0.55      0.37       467
#
#     accuracy                           0.84      5481
#    macro avg       0.62      0.71      0.64      5481
# weighted avg       0.90      0.84      0.86      5481
#
# F2 Score: 0.46322999279019467
# ROC AUC: 0.7719676127400025

# %% [markdown]
# **Analysis**
#
# - If the goal is to maximize recall for the positive class and maintain a higher F2-score, **the model before calibration** is preferable.
# - If accurate probability estimates are crucial and precision for the positive class is more important, **the model after calibration** is better.
#
# We will use the **non-calibrated** version of Final Model since `F2 score` and `Recall` is more important to us than `precision`

# %% [markdown]
# ### 6.2 Discriminant Threshold

# %%
thresholds = np.linspace(0, 1, 100)
f2_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_prob_best_model_xgb_hyp >= thresh).astype(int)
    f2_scores.append(fbeta_score(y_test, y_pred_thresh, beta=2))

# Find the threshold with the highest F2 score
optimal_idx = np.argmax(f2_scores)
optimal_threshold = thresholds[optimal_idx]
optimal_f2 = f2_scores[optimal_idx]

plt.figure()
plt.plot(thresholds, f2_scores, color='green', lw=2)
plt.axvline(optimal_threshold, color='red', linestyle='--', label='Optimal Threshold')
plt.xlabel('Threshold')
plt.ylabel('F2 Score')
plt.title('F2 Score vs. Threshold')
plt.legend(loc='best')
plt.show()

print(f"Optimal Threshold: {optimal_threshold}")
print(f"Optimal F2 Score: {optimal_f2}")
# Out:
# Optimal Threshold: 0.5050505050505051
# Optimal F2 Score: 0.4652425778421434

# %% [markdown]
# The graph shows the F2 Score as a function of the decision threshold for a classification model.
#
# 1. **F2 Score vs. Threshold**: The F2 score initially increases as the threshold increases from 0, reaches a peak, and then begins to decline. This indicates that the F2 score, which prioritizes recall more than precision, is sensitive to the threshold used for classification.
#
# 2. **Optimal Threshold**: The red dashed line indicates the optimal threshold, which maximizes the F2 score. At this threshold, the balance between precision and recall is such that recall is given more weight, minimizing the number of false negatives (as is typical when optimizing F2). The optimal threshold appears to be around 0.5, but it’s not exactly at 0.5, indicating that the model performs best with a slightly adjusted threshold.
#
# **Overall Conclusion**: Adjusting the classification threshold is crucial for optimizing the F2 score, especially when recall is more critical than precision. The plot suggests that selecting a threshold near the optimal value shown will help the model achieve the best balance between precision and recall for your specific use case, thereby improving its ability to correctly identify positive instances while minimizing false negatives.

# %% [markdown]
# ### 6.3 Learning Curves and Standard Deviation

# %% [markdown]
# #### 6.3.1 Learning Curves

# %%
def plot_learning_curve_with_std(estimator, title, X, y, X_test, y_test, scoring, cv=None, n_jobs=None, train_sizes=np.linspace(0.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring=scoring, return_times=False
    )
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    test_set_scores = []
    for train_size in train_sizes:
        X_train_subset = X[:train_size]
        y_train_subset = y[:train_size]
        
        estimator.fit(X_train_subset, y_train_subset)
        y_pred_test = estimator.predict(X_test)
        test_set_scores.append(fbeta_score(y_test, y_pred_test, beta=2))
    
    test_set_scores_mean = np.mean(test_set_scores)
    test_set_scores_std = np.std(test_set_scores)
    
    results_df_std = pd.DataFrame({
        'Training Size': train_sizes,
        'Train Mean Score': train_scores_mean,
        'Train Std Dev': train_scores_std,
        'CV Mean Score': test_scores_mean,
        'CV Std Dev': test_scores_std,
        'Test Mean Score': [test_set_scores_mean] * len(train_sizes),
        'Test Std Dev': [test_set_scores_std] * len(train_sizes)
    })
    
    print(results_df_std)
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    
    plt.plot(train_sizes, test_set_scores, 'o-', color="b", label="Testing score")
    plt.fill_between(train_sizes, np.array(test_set_scores) - test_set_scores_std,
                     np.array(test_set_scores) + test_set_scores_std, alpha=0.1, color="b")
    
    plt.legend(loc="best")
    plt.ylim(0, 1)
    plt.grid()
    return plt

title = "Learning Curves (XGboost)"
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scoring = make_scorer(fbeta_score, beta=2)

# Use the best model from GridSearchCV
estimator = best_model_xgb_hyp

plot_learning_curve_with_std(estimator, title, X_train, y_train, X_test, y_test, scoring=scoring, cv=cv, n_jobs=-1)
plt.show()
# Out:
#    Training Size  Train Mean Score  Train Std Dev  CV Mean Score  CV Std Dev  \
# 0           3551          0.557822       0.016424       0.438471    0.006832
# 1          11542          0.502910       0.010013       0.460086    0.012091
# 2          19533          0.490079       0.004950       0.463184    0.011177
# 3          27524          0.492980       0.003098       0.469422    0.009606
# 4          35515          0.490959       0.003038       0.471661    0.012227
#
#    Test Mean Score  Test Std Dev
# 0         0.448081      0.010847
# 1         0.448081      0.010847
# 2         0.448081      0.010847
# 3         0.448081      0.010847
# 4         0.448081      0.010847

# %% [markdown]
# The learning curves depicted in the graph provide insights into the performance of the LightGBM model as the number of training examples increases. Here's what the graph tells us:
#
# 1. **Training Score (Red Line)**: The training score starts relatively high but decreases slightly as more training examples are added. This is typical behavior, as the model initially fits the small training set well but starts to generalize better as more data is introduced.
#
# 2. **Cross-validation Score (Green Line)**: The cross-validation score starts lower than the training score, which is expected since cross-validation reflects the model's ability to generalize to unseen data. As the number of training examples increases, the cross-validation score improves and stabilizes, indicating that the model is learning effectively from the data and is generalizing well.
#
# 3. **Testing Score (Blue Line)**: The testing score, representing the model's performance on the test set, follows a similar trend to the cross-validation score. It starts low but improves and stabilizes as more training data is used. This convergence suggests that the model is not overfitting and is likely well-tuned.
#
# 4. **Convergence and Stability**: As the number of training examples increases, the training, cross-validation, and testing scores converge and stabilize around similar values. This convergence indicates that adding more data might not significantly improve the model's performance, as it has already learned the underlying patterns well.
#
# Overall, the graph suggests that the XGBoost model is performing adequately, with good generalization to new data as evidenced by the convergence of training, cross-validation, and testing scores. However, the relatively low overall scores might indicate that the model's performance could still be improved, possibly by further tuning, feature engineering, or trying different algorithms.

# %% [markdown]
# #### 6.3.2 Standard Deviation

# %%
def plot_learning_curve(estimator, title, X, y, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5), scoring=None):
    plt.figure()
    plt.title(title)
    plt.xlabel("Training examples")
    plt.ylabel("Score")

    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring=scoring)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")

    return train_scores_std, test_scores_std

f2_scorer = make_scorer(fbeta_score, beta=2)

title = "Learning Curves (XGBoost)"
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
train_std, test_std = plot_learning_curve(best_model_xgb_hyp, title, X_train, y_train, cv=cv, n_jobs=-1, scoring=f2_scorer)
plt.show()

# %%
stddata = {
    'Training STD': train_std,
    'Validation STD': test_std
}
df_stddata = pd.DataFrame(stddata)

df_stddata
# Out:
#    Training STD  Validation STD
# 0      0.016424        0.006832
# 1      0.010013        0.012091
# 2      0.004950        0.011177
# 3      0.003098        0.009606
# 4      0.003038        0.012227

# %% [markdown]
# The table shows the standard deviations (STD) of the training and validation scores over cross-validation. Here's what it tells us:
#
# 1. **Training STD**: The standard deviation of the training scores decreases as the iterations progress, starting at 0.016424 and dropping to 0.003038 by the last iteration. This decrease indicates that the model's performance on the training set becomes more consistent as the iterations proceed. A lower training STD suggests that the model is learning more stable patterns from the training data.
#
# 2. **Validation STD**: The standard deviation of the validation scores fluctuates slightly but remains within a similar range across the iterations, starting at 0.006832 and ending at 0.012227. The validation STD being relatively low suggests that the model's performance on the validation set is consistent, though there are minor fluctuations.
#
# 3. **Comparison**: The validation STD is generally lower than the training STD in the first iteration but becomes slightly higher in later iterations. This pattern may indicate that the model is stabilizing its training performance, but there is still some variability in how it generalizes to the validation set.
#
# Overall, this table suggests that the model's performance is becoming more stable across iterations, particularly on the training data. However, the slight variability in validation STD indicates that the model's performance on unseen data could still be subject to some inconsistency, which is not uncommon in model training processes. This might warrant additional tuning or further validation to ensure robustness.

# %% [markdown]
# ### 6.4 Time Complexity

# %%
# Measuring time to fit the model
start_time = time.time()
best_model_xgb_hyp.fit(X_train, y_train)
fit_time = time.time() - start_time
print(f"Time taken to fit the model: {fit_time:.4f} seconds")

# Measuring time to make predictions
start_time = time.time()
y_pred = best_model_xgb_hyp.predict(X_test)
predict_time = time.time() - start_time
print(f"Time taken to make predictions: {predict_time:.4f} seconds")
# Out:
# Time taken to fit the model: 19.1543 seconds
# Time taken to make predictions: 0.0494 seconds

# %% [markdown]
# **Timing Information**
#
# 1. **Model Training Time:** The model took approximately 19.1543 seconds to fit on the training data. This indicates that while XGBoost can be relatively fast, the training time can still be significant depending on the size of the dataset and the complexity of the model.
#
# 2. **Prediction Time:** Once the model is trained, it took only 0.0494 seconds to make predictions on the test data. This demonstrates that XGBoost is highly efficient in making predictions, even with potentially large and complex models.
#
# **Overall Conclusion:** XGBoost, while requiring some time to train, is extremely fast when it comes to making predictions. This makes it an excellent choice for applications where prediction speed is critical, such as real-time decision-making or large-scale deployment, despite the somewhat longer training times.

# %% [markdown]
# ### 6.5 Predict Unseen Data and Validation Sets

# %% [markdown]
# #### 6.5.1 Unseen Data

# %%
best_model_xgb_hyp.fit(X_train, y_train)

# Predict on test set
y_pred_unseen = best_model_xgb_hyp.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred_unseen))

f2 = fbeta_score(y_test, y_pred_unseen, beta=2)
print(f"F2 Score: {f2}")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      5014
#            1       0.28      0.55      0.37       467
#
#     accuracy                           0.84      5481
#    macro avg       0.62      0.71      0.64      5481
# weighted avg       0.90      0.84      0.86      5481
#
# F2 Score: 0.46322999279019467

# %%
cmunseen = confusion_matrix(y_test, y_pred_unseen)
print(cmunseen)

ax= plt.subplot()
sns.heatmap(cmunseen, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
# Out:
# [[4365  649]
#  [ 210  257]]

# %% [markdown]
# Our model seems to perform reasonably well on the unseen data, with little to almost no difference when compared to our Seen data

# %% [markdown]
# #### 6.5.2 Validation Sets (1-Fold)

# %%
X_train2, X_val, y_train2, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

ytestval=best_model_xgb_hyp.predict(X_val)
print(classification_report(y_val, ytestval))

f2 = fbeta_score(y_val, ytestval, beta=2)
print(f"F2 Score: {f2}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.91      4052
#            1       0.31      0.59      0.41       388
#
#     accuracy                           0.85      4440
#    macro avg       0.64      0.73      0.66      4440
# weighted avg       0.90      0.85      0.87      4440
#
# F2 Score: 0.5017528483786152

# %% [markdown]
# The result from predicting Validation Sets in single fold also gives us even a higher F2 score compared to Seen and Unseen Data, meaning it is working well

# %% [markdown]
# ### 6.7 Feature Importances

# %%
selected_numerical_features = numerical_features
selected_categorical_features = categorical_to_ohe

feature_importance = best_model_xgb_hyp.named_steps['classifier'].feature_importances_

# Get feature names
all_feature_names = (
    selected_numerical_features + 
    [f'{cat}_{val}' for cat in selected_categorical_features for val in X_train[cat].unique()]
)

print("Length of all_feature_names:", len(all_feature_names))
print("Length of feature_importance:", len(feature_importance))

# Adjusting feature names to match the length of feature importance
all_feature_names = all_feature_names[:len(feature_importance)]

feature_importance_df = pd.DataFrame({'feature': all_feature_names, 'importance': feature_importance})

feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['feature'], feature_importance_df['importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()
# Out:
# Length of all_feature_names: 24
# Length of feature_importance: 24

# %%
print(feature_importance_df)
# Out:
#                          feature  importance
# 3              length_of_service    0.145402
# 22                 department_HR    0.124762
# 19            department_Finance    0.084037
# 5                    awards_won?    0.083570
# 4             avg_training_score    0.075575
# 20          department_Analytics    0.058009
# 0                no_of_trainings    0.043772
# 15         department_Technology    0.042710
# 17  department_Sales & Marketing    0.036273
# 21              department_Legal    0.034527
# 2           previous_year_rating    0.033811
# 1                            age    0.033145
# 16        department_Procurement    0.031445
# 9          education_unspecified    0.031236
# 14                      gender_m    0.023641
# 23                department_R&D    0.022074
# 8      education_Below Secondary    0.021794
# 12  recruitment_channel_referred    0.019514
# 6           education_Bachelor's    0.012086
# 7     education_Master's & above    0.011045
# ...

# %% [markdown]
# The feature importance plot shows that the most influential factors for the model are:
#
# 1. **Length of Service**: The most important feature, indicating that employees with longer tenure are more likely to be promoted.
# 2. **Department (HR and Finance)**: These departments have significant weight in the promotion decision process.
# 3. **Awards Won**: Winning awards is a key factor in determining promotions.
# 4. **Average Training Score**: Employees with higher training scores are more likely to be considered for promotion.
# 5. **Department Analytics and Technology**: These also play a considerable role.
#
# On the other hand, features like **department operations**, **gender**, and **recruitment channels** have minimal impact on the promotion decision, suggesting that the model relies less on these attributes.

# %% [markdown]
# ### 6.8 About Our Final Model
#
# This section will discuss about our final model general information. Let's say it's a sub-conclusion of our conclusions

# %%
final_model = best_model_xgb_hyp

# %% [markdown]
# XGBoost is an optimized version of the Gradient Boosting algorithm that focuses on efficiency, scalability, and model performance. It uses a decision-tree-based approach to build models, where each new tree corrects the errors made by the previous ones. XGBoost stands out for its use of a regularization technique that helps prevent overfitting by penalizing complex models, leading to better generalization on unseen data.
#
# One of the key innovations in XGBoost is its use of a second-order Taylor approximation to optimize the objective function. This allows the algorithm to make more accurate updates to the model by considering both the gradient (first-order derivative) and the Hessian (second-order derivative). This approach leads to faster convergence and improved accuracy.
#
# Additionally, XGBoost employs several system-level optimizations, such as parallel processing, which allows it to handle large-scale datasets efficiently. It also includes features like sparsity awareness, which automatically handles missing values and makes the algorithm robust to datasets with a high degree of sparsity.
#
# Furthermore, XGBoost supports weighted quantile sketch, which helps in handling imbalanced datasets by giving more importance to the instances with higher weights, ensuring that the model performs well even in the presence of skewed data distributions.

# %%
final_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical preprocess',
#                                                   Pipeline(steps=[('scaling',
#                                                                    RobustScaler())]),
#                                                   ['no_of_trainings', 'age',
#                                                    'length_of_service',
#                                                    'previous_year_rating',
#                                                    'awards_won?',
#                                                    'avg_training_score']),
#                                                  ('categorical OHE',
#                                                   Pipeline(steps=[('one-hot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['education',
# ...

# %% [markdown]
# The image illustrates a machine learning pipeline that integrates several preprocessing steps and an XGBoost classifier (`XGBClassifier`) for model training and prediction. Below are the breakdowns of how it works :
#
#  1. **Preprocessor: ColumnTransformer**
#    - The pipeline starts with a `ColumnTransformer`, which allows different preprocessing to be applied to different subsets of features:
#      - **Numerical Preprocessing (`numerical preprocess`)**:
#        - The numerical features are processed using a `RobustScaler`.
#        - **RobustScaler**: This scaler is used to scale the numerical features by removing the median and scaling according to the Interquartile Range (IQR). It is particularly useful for data that contains outliers, as it is more robust to outliers than standard normalization methods.
#      - **Categorical Preprocessing (`categorical OHE`)**:
#        - The categorical features are transformed using a `OneHotEncoder`.
#        - **OneHotEncoder**: This encoder converts categorical variables into a form that could be provided to ML algorithms to do a better job in prediction. Specifically, it converts each category into a new binary column, representing whether each category is present (1) or not (0).
#
# 2. **SMOTEENN (Oversampling and Undersampling)**
#    - After preprocessing, the data is passed through `SMOTEENN`, which is a combination of SMOTE (Synthetic Minority Over-sampling Technique) and ENN (Edited Nearest Neighbors).
#      - **SMOTE**: This technique is used to generate synthetic examples in the minority class to balance the dataset.
#      - **ENN**: This technique is used to clean the dataset by removing instances in the majority class that are misclassified by their k-nearest neighbors.
#    - **Purpose**: The combination of SMOTE and ENN aims to improve the balance between classes in the dataset, addressing issues of class imbalance that might otherwise lead to biased models.
#
# 3. **XGBClassifier**
#    - Finally, the preprocessed and balanced data is fed into an `XGBClassifier`.
#    - **XGBClassifier**: This is the XGBoost classifier, a powerful and efficient implementation of the gradient boosting algorithm. It builds an ensemble of trees by focusing on the errors of previous models, creating a robust model that performs well on both training and unseen data.
#
# **Overall Workflow:**
# 1. The pipeline begins by preprocessing the data using appropriate techniques for numerical and categorical features.
# 2. After preprocessing, the data is rebalanced using SMOTEENN to handle class imbalance.
# 3. The rebalanced and preprocessed data is then used to train an XGBoost classifier.
# 4. The pipeline is designed to be a seamless, end-to-end solution where raw data can be fed into the pipeline, and the output will be predictions from the trained XGBoost model.
#
# This pipeline is particularly useful in scenarios where the dataset has both numerical and categorical features, as well as issues with class imbalance. The preprocessing steps ensure that the data is properly prepared before training, and the XGBoost classifier provides a robust model that is likely to perform well on various types of data.

# %% [markdown]
# ## **7. Conclusion And Recommendations**

# %% [markdown]
# #### 7.1.1 Model Conclusions :

# %%
report_final = classification_report(y_test, y_pred_best_model_xgb_hyp)
print('Final Model Report : \n', report_final)
f2 = fbeta_score(y_test, y_pred_best_model_xgb_hyp, beta=2)
print(f"F2 Score: {f2}")
roc_auc = roc_auc_score(y_test, y_prob_best_model_xgb_hyp)
print(f"ROC AUC: {roc_auc}")
# Out:
# Final Model Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91      5014
#            1       0.28      0.55      0.37       467
#
#     accuracy                           0.84      5481
#    macro avg       0.62      0.71      0.64      5481
# weighted avg       0.90      0.84      0.86      5481
#
# F2 Score: 0.46322999279019467
# ROC AUC: 0.7762707673332656

# %% [markdown]
# The final model report provides several important performance metrics that allow us to evaluate how well the model is performing, especially with regard to classifying the positive class. Here are the key takeaways:
#
# 1. **Class 0 (Negative Class) Performance:**
#    - **Precision**: 0.95, indicating that when the model predicts the negative class, it is correct 95% of the time.
#    - **Recall**: 0.87, meaning that the model correctly identifies 87% of the actual negative class instances.
#    - **F1-Score**: 0.91, which is a good balance between precision and recall, indicating strong performance in identifying the negative class.
#
# 2. **Class 1 (Positive Class) Performance:**
#    - **Precision**: 0.28, meaning that only 28% of the instances predicted as positive are actually positive, which is quite low.
#    - **Recall**: 0.55, indicating that the model correctly identifies 55% of the actual positive class instances, which shows some improvement in sensitivity but is still moderate.
#    - **F1-Score**: 0.37, reflecting a balance between precision and recall, but still indicating that the model struggles with the positive class.
#
# 3. **Overall Model Performance:**
#    - **Accuracy**: 0.84, showing that the model is correct 84% of the time, but this might be misleading given the class imbalance.
#    - **Macro Avg (F1-Score)**: 0.64, which averages the F1-scores for both classes and indicates moderate overall performance.
#    - **Weighted Avg (F1-Score)**: 0.86, which takes into account the class imbalance and weights the F1-scores by support (number of instances in each class). This shows a better overall performance when considering class proportions.
#
# 4. **F2 Score:**
#    - **F2 Score**: 0.46, indicating that the model is somewhat better at prioritizing recall over precision, which aligns with your focus on reducing false negatives.
#
# 5. **ROC AUC:**
#    - **ROC AUC**: 0.776, suggesting that the model has a reasonable ability to distinguish between the positive and negative classes. A value closer to 1 would indicate a better performance, so there's room for improvement.
#
# **Conclusion:**
# - The model performs very well in identifying the negative class (class 0) but struggles with the positive class (class 1), which is indicated by the low precision, recall, and F1-score for class 1.
# - The overall accuracy and weighted F1-score are high, but this is likely influenced by the class imbalance, where the negative class dominates.
# - The F2 score of 0.46 shows that the model is somewhat effective at minimizing false negatives, but the performance is not optimal.
# - The ROC AUC of 0.776 is decent but indicates that there is still potential to improve the model's discriminative power.

# %%
best_params = random_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'classifier__subsample': 0.8, 'classifier__n_estimators': 100, 'classifier__max_depth': 3, 'classifier__learning_rate': 0.1}

# %% [markdown]
# - Our Final model best parameter from Hyperparameter tuning are :
#
#     1. classifier__subsample: 0.8
#     2. classifier__n_estimators: 100
#     3. classifier__max_depth: 3
#     4. classifier__learning_rate: 0.1

# %% [markdown]
# The output displayed shows the best parameters identified by a `random_search` for an XGBoost classifier within a pipeline. These parameters were likely found through a random search optimization process, which tests various combinations of hyperparameters to find the ones that yield the best performance for the model. Here’s what each parameter means:
#
# 1. **`classifier__subsample`: 0.8**
#    - This parameter controls the fraction of the training data that is randomly selected to grow each tree. A value of 0.8 means that each tree in the model will be trained on 80% of the data, helping to prevent overfitting by introducing randomness and variability into the model.
#
# 2. **`classifier__n_estimators`: 100**
#    - This parameter specifies the number of trees (estimators) in the ensemble. In this case, the model will consist of 100 trees. More trees generally improve model performance up to a point, but they also increase computational cost and the risk of overfitting.
#
# 3. **`classifier__max_depth`: 3**
#    - This is the maximum depth of each individual tree. A depth of 3 means that each tree can have at most 3 levels of splits. Shallower trees (lower depth) generally help prevent overfitting by limiting the model’s complexity.
#
# 4. **`classifier__learning_rate`: 0.1**
#    - The learning rate controls the contribution of each tree to the final model. A value of 0.1 is fairly common and strikes a balance between the model’s ability to learn (too high a rate can cause overfitting, while too low a rate can make the model underfit by being too conservative in updates).
#
# **Overall Interpretation:**
# These hyperparameters suggest a model configuration that aims to balance complexity with generalization. With 100 trees (moderately sized ensemble), a maximum depth of 3 (simple trees), a learning rate of 0.1 (moderate), and subsampling of 80%, the model is likely tuned to avoid overfitting while still capturing meaningful patterns in the data. This configuration is a common approach in gradient boosting models, where the focus is on building a robust model that generalizes well to unseen data.

# %% [markdown]
# ### MODEL TRUSTWORTHINESS

# %% [markdown]
# **Below are insights into factors that could affect the trustworthiness of our model:**
#
# - **Imbalanced Data**: As indicated by the classification reports, if one class is significantly underrepresented, the model may perform poorly on that class.
# - **Insufficient Data**: The learning curves suggest that more training data could improve model performance.
# - **Poor Quality Data**: Noise, errors, and outliers in the data can lead to unreliable model predictions
#
# By ensuring comprehensive and appropriate preprocessing, addressing class imbalance, and improving data quality, we can enhance the trustworthiness of our model.

# %% [markdown]
# ### SHAP VALUES

# %%
xgb_hyp_forshap = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('SMOTEENN', SMOTEENN(random_state=42))
])

X_train_over, y_train_over = xgb_hyp_forshap.fit_resample(X_train, y_train)

# %%
best_model_xgb_hyp['classifier']
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               class_weight='balanced', colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
explainer = shap.TreeExplainer(best_model_xgb_hyp['classifier'])
shap_values = explainer.shap_values(X_train_over)
shap_values_matrix = np.vstack(shap_values)

shap.summary_plot(shap_values_matrix, X_train_over, feature_names=all_feature_names)

# %% [markdown]
# The SHAP summary plot provides insights into how individual features influence the model's predictions:
#
# 1. **Awards Won and Length of Service**: These are the most influential features. Higher values for these features (e.g., having won awards and longer service) significantly increase the likelihood of promotion.
#
# 2. **Department HR and Average Training Score**: Employees in HR and those with higher training scores also have a strong positive impact on promotion decisions.
#
# 3. **Age and Finance Department**: These features have a moderate influence, with older age and being in the Finance department generally associated with a higher chance of promotion.
#
# 4. **No. of Trainings and Previous Year Rating**: These features also contribute positively, but to a lesser extent.
#
# 5. **Other Features**: Features like gender, recruitment channels, and education level have less impact on the model’s predictions, suggesting they are less influential in determining promotions.
#
# Overall, the plot shows that the model heavily relies on specific features like awards won, length of service, and department, while other features have a more minor influence.

# %% [markdown]
# ### **The Impact of Final Model in Business :**
#
# **Cost without the model**
#
# the cost is the sum of all the possible Class 1 multiplied by the cost of a Type 2 Error (False Negative).
#
# - Total customers: 486
# - Cost per Type 2 Error (False Negative): $ 5900
#
# Total cost without the model = 5481 * 5900 = $ 32,337,900
#
# **Cost with the model (From Unseen Data Metrics)**
#
# Using the confusion matrix values:
# - False Positives (FP): 649
# - False Negatives (FN): 210
#
# And the costs associated with the errors:
# - Cost per Type 1 Error (False Positive): $1200
# - Cost per Type 2 Error (False Negative): $5900
#
# The total cost with the model is calculated by summing the costs of the false positives and false negatives:
#
# (FP * Cost per FP) + (FN * Cost per FN)
# = (649 * 1200) + (210 * 5900)
# = $ 2,017,800
#
# Total savings = $ 32,337,900 - $ 2,017,800 = **$ 30,320,100**
#
# The company could save **$ 30,320,100** by using the model to predict customer churn compared to not using any model.

# %% [markdown]
# ### **Recommendations For Business :**
#
#
# 1. **Enhance Employee Recognition Programs**
#    - **Observation**: "Awards won" is a significant factor in determining promotions.
#    - **Recommendation**: Invest in and expand employee recognition programs. Create more opportunities for employees to be acknowledged for their achievements. This could include monthly or quarterly awards that recognize both individual and team contributions. Ensuring that employees feel recognized will likely improve engagement and retention, especially among high performers.
#
# 2. **Strengthen Career Development Pathways**
#    - **Observation**: "Length of service" and "average training score" are important predictors of promotion.
#    - **Recommendation**: Develop and communicate clear career progression paths for employees. Implement or expand on structured training programs that are aligned with promotion criteria. This could include mentorship programs, leadership development courses, and upskilling opportunities. Employees should have a clear understanding of how they can advance within the company, which will help retain talent and encourage continuous professional development.
#
# 3. **Optimize Talent Management in Key Departments**
#    - **Observation**: Certain departments, such as HR and Finance, are more likely to have employees promoted.
#    - **Recommendation**: Evaluate why these departments are more successful in advancing their employees. Is it because they have better development programs or because of different operational needs? Use this insight to apply best practices from these departments across the company, or to re-evaluate the promotion processes in other departments to ensure fairness and consistency.
#
# 4. **Prioritize Retention of High-Value Employees**
#    - **Observation**: Misclassifications (false negatives) can lead to missed opportunities for promoting deserving employees, which may result in turnover.
#    - **Recommendation**: Implement retention strategies for employees who are at risk of being overlooked for promotions. This could include targeted development plans, personalized career discussions, and even retention bonuses for high-potential employees. Consider conducting regular “talent reviews” to ensure that high performers are on track and not being overlooked due to model errors.
#
# 5. **Align Promotion Criteria with Business Objectives**
#    - **Observation**: The model places heavy importance on objective metrics like tenure and performance scores.
#    - **Recommendation**: Ensure that your promotion criteria align with broader business objectives. If innovation, leadership, or customer satisfaction are key drivers of your business, these should be reflected in how employees are evaluated for promotions. Revisit promotion policies regularly to align with the evolving needs of the business.
#
# 6. **Promote a Culture of Continuous Learning**
#    - **Observation**: Higher training scores correlate strongly with promotions.
#    - **Recommendation**: Foster a culture where continuous learning is highly valued and rewarded. Encourage employees to pursue additional training and certifications, perhaps offering incentives for those who do. Consider creating an internal learning platform where employees can track their progress and see how it aligns with their career growth within the company.
#
# 7. **Ensure Fairness and Equity in Promotion Processes**
#    - **Observation**: Some demographic factors like gender and department have a lower impact on promotions.
#    - **Recommendation**: Conduct regular audits of your promotion processes to ensure they are fair and equitable. Address any unconscious biases that might exist in the promotion criteria. This could include implementing blind review processes or ensuring diversity on promotion panels. Ensuring fairness will not only help in retaining a diverse workforce but also in fostering an inclusive company culture.
#
# 8. **Invest in Data-Driven HR Practices**
#    - **Observation**: Data insights from the model highlight important trends in employee promotions.
#    - **Recommendation**: Leverage data analytics to continually improve HR practices. Consider investing in more advanced HR analytics tools that can provide real-time insights into employee performance, engagement, and potential for promotion. Use these tools to proactively identify and nurture top talent.
#
# By implementing these business-driven recommendations, the company can enhance its talent management practices, align its promotion processes with business goals, and ensure that it is maximizing the potential of its workforce in a fair and equitable manner.

# %% [markdown]
# ### **Recommendations For Improving Final Model :**
#
# - Try other ML algorithms and also retry hyperparameter tuning with different parameters.
# - Experiment with different oversampling techniques other than the three experiments we conducted above.
# - Increase the data, especially for the minority class (is_promoted), to help improve the model's performance by eliminating data imbalance.
# - Analyze the data for instances where the model still has False Negatives and False Positives to understand their reasons and characteristics.

# %% [markdown]
# ## **8. Deployment**

# %%
# Save the model
joblib.dump(best_model_xgb_hyp, 'best_model_xgb_hyp.pkl')
# Out:
# ['best_model_xgb_hyp.pkl']
